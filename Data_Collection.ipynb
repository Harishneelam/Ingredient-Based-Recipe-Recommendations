# %% [markdown]
# ## 1. Dietary Considerations

# %%
import requests
from bs4 import BeautifulSoup

Tts = []
Ingrd = []
DTC = []

for page_number in range(1, 15):
    base_url = f'https://recipeland.com/recipes/for/diabetic-10?page={page_number}' ##Diabetic
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Diabetic")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")


for page_number in range(1, 20):
    base_url = f'https://recipeland.com/recipes/for/gluten-free-162?page={page_number}' ##Glutenfree
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Gluten-Free")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

                    

for page_number in range(1, 7):
    base_url = f'https://recipeland.com/recipes/for/low-carb-660?page={page_number}' ##Low-Carbs
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Low-Carb")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

for page_number in range(1, 30):
    base_url = f'https://recipeland.com/recipes/for/low-fat-7?page={page_number}' ##Low-Fat
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Low-Fat")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")
                    
                    
for page_number in range(1, 40):
    base_url = f'https://recipeland.com/recipes/list?page={page_number}' ##Standard
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Standard")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

# %%
import pandas as pd
import re
import json

columns = ['Title', 'Ingredients','DTC']
df = pd.DataFrame(columns=columns)

df['Title'] = Tts
df['Ingredients'] = Ingrd
df['DTC'] = DTC

df.to_pickle('Recipes_data_Dietary.pkl')

# %% [markdown]
# ## Cultural Cuisines

# %%
import requests
from bs4 import BeautifulSoup

Tts = []
Ingrd = []
DTC = []

for page_number in range(1, 15):
    base_url = f'https://recipeland.com/recipes/for/africa-middle-east-604?page={page_number}'
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Africa & Middle East")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")


for page_number in range(1, 25):
    base_url = f'https://recipeland.com/recipes/for/asian-280?page={page_number}' ##Asian
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Asian")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

                    

for page_number in range(1, 40):
    base_url = f'https://recipeland.com/recipes/for/indian-100?page={page_number}' ##Indian
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Indian")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

for page_number in range(1, 50):
    base_url = f'https://recipeland.com/recipes/for/europe-606?page={page_number}' ##European
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("European")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")
                    
                    
for page_number in range(1, 12):
    base_url = f'https://recipeland.com/recipes/for/american-116?page={page_number}' ##American
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("American")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

for page_number in range(1, 50):
    base_url = f'https://recipeland.com/recipes/for/mexican-3?page={page_number}' ##Mexican
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Mexican")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

# %%
columns = ['Title', 'Ingredients','Cuisine']
df = pd.DataFrame(columns=columns)

df['Title'] = Tts
df['Ingredients'] = Ingrd
df['Cuisine'] = DTC

df.to_pickle('Recipes_data_Cuisines.pkl')

# %% [markdown]
# ## 3. Course Meals

# %%
import requests
from bs4 import BeautifulSoup

Tts = []
Ingrd = []
DTC = []

for page_number in range(1, 63):
    base_url = f'https://recipeland.com/recipes/for/breakfasts-brunch-111?page={page_number}'
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Breakfast and Brunch")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")


for page_number in range(1, 63):
    base_url = f'https://recipeland.com/recipes/for/dessert-46?page={page_number}' ##Asian
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Dessert")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

                    

for page_number in range(1, 63):
    base_url = f'https://recipeland.com/recipes/for/main-dish-29?page={page_number}'
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Main Dish")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

for page_number in range(1, 63):
    base_url = f'https://recipeland.com/recipes/for/side-dish-9?page={page_number}' ##European
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Side Dish")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")
                    
                    
for page_number in range(1, 63):
    base_url = f'https://recipeland.com/recipes/for/appetizers-25?page={page_number}' ##American
    response = requests.get(base_url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        recipe_links = soup.select('.col-md-8 h2 a')

        for recipe_link in recipe_links:
            recipe_url = recipe_link['href']
            recipe_response = requests.get(recipe_url)

            if recipe_response.status_code == 200:
                recipe_soup = BeautifulSoup(recipe_response.text, 'html.parser')
                recipe_title = recipe_soup.find('h1',class_ = 'mx-0')
                ingredient_table = recipe_soup.find('table', {'id': 'ingredient_list'})

                if ingredient_table:
                    rows = ingredient_table.find_all('tr')
                    Ings = []
                    
                    for row in rows:
                        cells = row.find_all('td')
                        
                        if len(cells) >= 3:
                            ingredient_cell = cells[2]
                            ingredient_link = ingredient_cell.find('a')

                            if ingredient_link:
                                ingredient_text = ingredient_link.text
                                Ings.append(ingredient_text)
                            
                    Ingrd.append(Ings)
                else:
                    Ingrd.append("Ingredients Not Found")
                DTC.append("Appetizers")
                if recipe_title:
                    recipe_title_text = Tts.append(recipe_title.text)
                else:
                    recipe_title_text = Tts.append("Title not found")

# %%
columns = ['Title', 'Ingredients','Course']
df = pd.DataFrame(columns=columns)

df['Title'] = Tts
df['Ingredients'] = Ingrd
df['Cuisine'] = DTC

df.to_pickle('Recipes_data_Course.pkl')
