# %%
import pandas as pd
import re

df1 = pd.read_pickle('Recipes_data_Dietary.pkl')
df2 = pd.read_pickle('Recipes_data_Cuisines.pkl')
df3 = pd.read_pickle('Recipes_data_Course.pkl')

# %%
df1.columns = ['Title', 'Ingredients', 'Type']
df2.columns = ['Title', 'Ingredients', 'Type']
df3.columns = ['Title', 'Ingredients', 'Type']

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)

# %%
def process_ingredients(data):
    data = [re.sub(r'[^a-zA-Z\s]', '', ingredient) for ingredient in data]
    data = [re.sub(r'\([^)]*\)', '', ingredient) for ingredient in data]
    data = list(filter(None, data))
    data = [ingredient.replace('scallions spring or green onions', 'green onions') for ingredient in data]
    data = [ingredient for ingredient in data if len(ingredient) >= 1]
    data = [' '.join(ingredient.split()) for ingredient in data]
    data = [ingredient.split(',')[0] for ingredient in data]
    
    return data



df['Title'] = df['Title'].apply(lambda p: re.sub(r'\([^)]*\)', '', p))

df['Ingredients'] = df['Ingredients'].apply(process_ingredients)
df['Ingredients'] = df['Ingredients'].apply(lambda x: list(set(x)))

df = df.drop_duplicates(subset=['Title','Type'], keep='first')
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                       Title  \
# 0                     Alice's Key Lime Pie
# 1                 Carrot Cake Muffin Treats
# 2                     Creamy Cucumber Salad
# 3              Creamy Ranch Salad Dressing
# 4                Diabetic Blueberry Muffins
# ...                                     ...
# 9783                Pork and Scallion Wraps
# 9784                  Pork U Pine Meatballs
# 9785                  Portuguese Garlic Dip
# 9786     Potato Skins with Cheese and Bacon
# 9787  Potato Tatin with Brie and Prosciutto
#
#                                             Ingredients        Type
# 0     [lime juice, vanilla extract, sugar substitute...    Diabetic
# 1     [raisins seedless, nutmeg, baking soda, walnut...    Diabetic
# 2     [vinegar, garlic, yogurt plain, black pepper, ...    Diabetic
# 3     [oregano, green onions, yogurt lowfat, cottage...    Diabetic
# 4     [lemon zest, blueberries, biscuit baking mix b...    Diabetic
# ...                                                 ...         ...
# 9783  [hoisin sauce, pork tenderloin, soy sauce tama...  Appetizers
# 9784          [rice, ground beef, tomato sauce, onions]  Appetizers
# 9785  [mayonnaise, worcestershire sauce, garlic clov...  Appetizers
# 9786  [chives, russet potatoes, cheddar cheese very ...  Appetizers
# 9787  [shallots, cream, nutmeg, salt and black peppe...  Appetizers
#
# [9788 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(tokenizer=lambda x: x, lowercase=False)
X = vectorizer.fit_transform(df['Ingredients'])
# Out:
# /Users/harishneelam/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
def jaccard_similarity(str1, str2):
    a = set(str1.split())
    b = set(str2.split())
    intersection = len(a.intersection(b))
    union = len(a) + len(b) - intersection
    similarity = intersection / union
    return similarity

def remove_colors(string, color_list):
    pattern = re.compile(r'\b(?:' + '|'.join(re.escape(color) for color in color_list) + r')\b', flags=re.IGNORECASE)
    string_without_colors = re.sub(pattern, '', string)
    return string_without_colors.strip()


strings = vectorizer.get_feature_names_out()

color_words = ['red', 'blue', 'green', 'yellow','white','black','brown','english','extract']
exclude_words = ["ground", "sauce", "milk", "oil","seeds","powder","flour","crumbs","broth","salt","beef","zest","vinegar","paste","juice","shortening","noodles","stock"]
smst = []

for i in range(len(strings)):
    for j in range(i + 1, len(strings)):
        str1 = remove_colors(strings[i], color_words)
        str2 = remove_colors(strings[j], color_words)
        similarity = jaccard_similarity(str1, str2)
        if(similarity >= 0.5):
            smst.append([strings[i],strings[j]])
            print(f"Jaccard_similarity between '{strings[i]}' and '{strings[j]}': {similarity}")
# Out:
# Jaccard_similarity between 'Chinese rice vinegar' and 'brown rice vinegar': 0.6666666666666666
# Jaccard_similarity between 'Chinese rice vinegar' and 'japanese rice vinegar': 0.5
# Jaccard_similarity between 'Chinese rice vinegar' and 'rice vinegar': 0.6666666666666666
# Jaccard_similarity between 'Chinese sausage' and 'sausage': 0.5
# Jaccard_similarity between 'Italian Dressing' and 'Italian Dressing Mix': 0.6666666666666666
# Jaccard_similarity between 'Parmesan cheese' and 'blue cheese': 0.5
# Jaccard_similarity between 'Parmesan cheese' and 'cheese': 0.5
# Jaccard_similarity between 'Whole wheat crackers' and 'stoneground wheat crackers': 0.5
# Jaccard_similarity between 'active starter' and 'starter': 0.5
# Jaccard_similarity between 'adobo sauce' and 'sauce': 0.5
# Jaccard_similarity between 'aioli sauce' and 'sauce': 0.5
# Jaccard_similarity between 'alba chocolate' and 'chocolate': 0.5
# Jaccard_similarity between 'alba chocolate' and 'chocolate extract': 0.5
# Jaccard_similarity between 'alba chocolate' and 'white chocolate': 0.5
# Jaccard_similarity between 'alfredo sauce' and 'sauce': 0.5
# Jaccard_similarity between 'allbran cereal' and 'cereal': 0.5
# Jaccard_similarity between 'allpurpose flour' and 'unbleached allpurpose flour': 0.6666666666666666
# Jaccard_similarity between 'allspice' and 'allspice berries': 0.5
# Jaccard_similarity between 'allspice berries' and 'berries': 0.5
# Jaccard_similarity between 'almond butter' and 'almond extract': 0.5
# Jaccard_similarity between 'almond butter' and 'butter': 0.5
# Jaccard_similarity between 'almond extract' and 'almond meal': 0.5
# Jaccard_similarity between 'almond extract' and 'almond milk': 0.5
# Jaccard_similarity between 'almond extract' and 'almond oil': 0.5
# Jaccard_similarity between 'almond extract' and 'almond paste': 0.5
# Jaccard_similarity between 'almond extract' and 'almond powder': 0.5
# Jaccard_similarity between 'almond meal' and 'meal': 0.5
# Jaccard_similarity between 'almond milk' and 'milk': 0.5
# Jaccard_similarity between 'amaranth cereal' and 'cereal': 0.5
# Jaccard_similarity between 'amaretto liqueur' and 'liqueur': 0.5
# Jaccard_similarity between 'american cheese' and 'blue cheese': 0.5
# Jaccard_similarity between 'american cheese' and 'cheese': 0.5
# Jaccard_similarity between 'anasazi beans' and 'beans': 0.5
# Jaccard_similarity between 'anasazi beans' and 'black beans': 0.5
# Jaccard_similarity between 'anasazi beans' and 'brown beans': 0.5
# Jaccard_similarity between 'anasazi beans' and 'green beans': 0.5
# Jaccard_similarity between 'anasazi beans' and 'red beans': 0.5
# Jaccard_similarity between 'anasazi beans' and 'white beans': 0.5
# Jaccard_similarity between 'anise extract' and 'star anise': 0.5
# Jaccard_similarity between 'apple brandy' and 'brandy': 0.5
# Jaccard_similarity between 'apple brandy' and 'calvados apple brandy': 0.6666666666666666
# Jaccard_similarity between 'apple butter' and 'butter': 0.5
# Jaccard_similarity between 'apple cider' and 'apple cider vinegar': 0.6666666666666666
# Jaccard_similarity between 'apple jelly' and 'jelly': 0.5
# Jaccard_similarity between 'apple juice' and 'apple juice concentrate': 0.6666666666666666
# Jaccard_similarity between 'apple juice' and 'juice': 0.5
# Jaccard_similarity between 'apple juice concentrate' and 'pineapple juice concentrate': 0.5
# Jaccard_similarity between 'apple pie filling' and 'apple pie spice': 0.5
# Jaccard_similarity between 'apple pie filling' and 'blueberry pie filling': 0.5
# Jaccard_similarity between 'apple pie filling' and 'cherry pie filling': 0.5
# Jaccard_similarity between 'apple pie filling' and 'lemon pie filling': 0.5
# Jaccard_similarity between 'apple pie filling' and 'peach pie filling': 0.5
# Jaccard_similarity between 'apple pie spice' and 'pumpkin pie spice': 0.5
# Jaccard_similarity between 'apple wine' and 'red wine': 0.5
# Jaccard_similarity between 'apple wine' and 'white wine': 0.5
# Jaccard_similarity between 'apple wine' and 'wine': 0.5
# Jaccard_similarity between 'apples' and 'apples mcintosh': 0.5
# Jaccard_similarity between 'apples' and 'apples red delicious': 0.5
# Jaccard_similarity between 'apricot brandy' and 'brandy': 0.5
# Jaccard_similarity between 'apricot sauce' and 'sauce': 0.5
# Jaccard_similarity between 'armadillo meat' and 'meat': 0.5
# Jaccard_similarity between 'armadillo meat' and 'meat extract': 0.5
# Jaccard_similarity between 'artichokes' and 'jerusalem artichokes': 0.5
# Jaccard_similarity between 'asadero cheese' and 'blue cheese': 0.5
# Jaccard_similarity between 'asadero cheese' and 'cheese': 0.5
# Jaccard_similarity between 'asiago cheese' and 'blue cheese': 0.5
# Jaccard_similarity between 'asiago cheese' and 'cheese': 0.5
# Jaccard_similarity between 'baby carrots' and 'carrots': 0.5
# Jaccard_similarity between 'baby corn' and 'corn': 0.5
# Jaccard_similarity between 'baby corn' and 'yellow corn': 0.5
# Jaccard_similarity between 'baby lima beans' and 'lima beans': 0.6666666666666666
# Jaccard_similarity between 'baby shrimp' and 'shrimp': 0.5
# Jaccard_similarity between 'baby spinach' and 'spinach': 0.5
# Jaccard_similarity between 'baby vidalia onions' and 'sweet vidalia onions': 0.5
# Jaccard_similarity between 'bacon' and 'bacon bits': 0.5
# Jaccard_similarity between 'bacon' and 'bacon drippings': 0.5
# Jaccard_similarity between 'bacon' and 'turkey bacon': 0.5
# Jaccard_similarity between 'bacon bits' and 'imitation bacon bits': 0.6666666666666666
# Jaccard_similarity between 'bacon drippings' and 'drippings': 0.5
# Jaccard_similarity between 'balsamella sauce' and 'sauce': 0.5
# Jaccard_similarity between 'balsamic vinaigrette' and 'vinaigrette': 0.5
# Jaccard_similarity between 'balsamic vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'balsamic vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'balsamic vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'balti sauce' and 'sauce': 0.5
# Jaccard_similarity between 'bamboo skewers' and 'skewers': 0.5
# Jaccard_similarity between 'barbecue beans' and 'beans': 0.5
# Jaccard_similarity between 'barbecue beans' and 'black beans': 0.5
# Jaccard_similarity between 'barbecue beans' and 'brown beans': 0.5
# Jaccard_similarity between 'barbecue beans' and 'green beans': 0.5
# Jaccard_similarity between 'barbecue beans' and 'red beans': 0.5
# Jaccard_similarity between 'barbecue beans' and 'white beans': 0.5
# Jaccard_similarity between 'barbecue sauce' and 'sauce': 0.5
# Jaccard_similarity between 'basic red sauce' and 'sauce': 0.5
# Jaccard_similarity between 'basil' and 'basil pesto': 0.5
# Jaccard_similarity between 'basmati rice' and 'brown rice': 0.5
# Jaccard_similarity between 'basmati rice' and 'rice': 0.5
# Jaccard_similarity between 'bay scallops' and 'scallops': 0.5
# Jaccard_similarity between 'bean curd' and 'bean curd cake': 0.6666666666666666
# Jaccard_similarity between 'bean curd' and 'bean curd sheets': 0.6666666666666666
# Jaccard_similarity between 'bean curd cake' and 'bean curd sheets': 0.5
# Jaccard_similarity between 'bean paste' and 'soy bean paste': 0.6666666666666666
# Jaccard_similarity between 'bean paste' and 'szechuan hot bean paste': 0.5
# Jaccard_similarity between 'beans' and 'black beans': 1.0
# Jaccard_similarity between 'beans' and 'black gram beans': 0.5
# Jaccard_similarity between 'beans' and 'brown beans': 1.0
# Jaccard_similarity between 'beans' and 'chili beans': 0.5
# Jaccard_similarity between 'beans' and 'cranberry beans': 0.5
# Jaccard_similarity between 'beans' and 'fava beans': 0.5
# Jaccard_similarity between 'beans' and 'green beans': 1.0
# Jaccard_similarity between 'beans' and 'jelly beans': 0.5
# Jaccard_similarity between 'beans' and 'lima beans': 0.5
# Jaccard_similarity between 'beans' and 'long beans': 0.5
# Jaccard_similarity between 'beans' and 'mung beans': 0.5
# Jaccard_similarity between 'beans' and 'navy beans': 0.5
# Jaccard_similarity between 'beans' and 'pinto beans': 0.5
# Jaccard_similarity between 'beans' and 'red beans': 1.0
# Jaccard_similarity between 'beans' and 'red kidney beans': 0.5
# Jaccard_similarity between 'beans' and 'refried beans': 0.5
# Jaccard_similarity between 'beans' and 'wax beans': 0.5
# Jaccard_similarity between 'beans' and 'white beans': 1.0
# Jaccard_similarity between 'beans' and 'white nothern beans': 0.5
# Jaccard_similarity between 'beans ranch style' and 'ranch style beans': 1.0
# Jaccard_similarity between 'bechamel white sauce' and 'sauce': 0.5
# Jaccard_similarity between 'beef' and 'beef base': 0.5
# Jaccard_similarity between 'beef' and 'beef brisket': 0.5
# Jaccard_similarity between 'beef' and 'beef chuck': 0.5
# Jaccard_similarity between 'beef' and 'beef gravy': 0.5
# Jaccard_similarity between 'beef' and 'beef kidneys': 0.5
# Jaccard_similarity between 'beef' and 'beef liver': 0.5
# Jaccard_similarity between 'beef' and 'beef roast': 0.5
# Jaccard_similarity between 'beef' and 'beef steak': 0.5
# Jaccard_similarity between 'beef' and 'beef stock': 0.5
# Jaccard_similarity between 'beef' and 'beef suet': 0.5
# Jaccard_similarity between 'beef' and 'beef tenderloin': 0.5
# Jaccard_similarity between 'beef' and 'corned beef': 0.5
# Jaccard_similarity between 'beef' and 'ground beef': 0.5
# Jaccard_similarity between 'beef' and 'roast beef': 0.5
# Jaccard_similarity between 'beef' and 'stewing beef': 0.5
# Jaccard_similarity between 'beef blade steak' and 'beef chuck steak': 0.5
# Jaccard_similarity between 'beef blade steak' and 'beef round steak': 0.5
# Jaccard_similarity between 'beef blade steak' and 'beef sirloin steak': 0.5
# Jaccard_similarity between 'beef blade steak' and 'beef skirt steak': 0.5
# Jaccard_similarity between 'beef blade steak' and 'beef steak': 0.6666666666666666
# Jaccard_similarity between 'beef blade steak' and 'beef tbone steak': 0.5
# Jaccard_similarity between 'beef bouillon cubes' and 'beef bouillon granules': 0.5
# Jaccard_similarity between 'beef bouillon cubes' and 'bouillon cubes': 0.6666666666666666
# Jaccard_similarity between 'beef bouillon cubes' and 'chicken bouillon cubes': 0.5
# Jaccard_similarity between 'beef chuck' and 'beef chuck roast': 0.6666666666666666
# Jaccard_similarity between 'beef chuck' and 'beef chuck steak': 0.6666666666666666
# Jaccard_similarity between 'beef chuck' and 'ground chuck ground beef': 0.6666666666666666
# Jaccard_similarity between 'beef chuck roast' and 'beef chuck steak': 0.5
# Jaccard_similarity between 'beef chuck roast' and 'beef roast': 0.6666666666666666
# Jaccard_similarity between 'beef chuck roast' and 'beef roast pot roast': 0.5
# Jaccard_similarity between 'beef chuck roast' and 'beef roast ribeye': 0.5
# Jaccard_similarity between 'beef chuck roast' and 'beef roast rump': 0.5
# Jaccard_similarity between 'beef chuck roast' and 'ground chuck ground beef': 0.5
# Jaccard_similarity between 'beef chuck roast' and 'roast beef': 0.6666666666666666
# Jaccard_similarity between 'beef chuck steak' and 'beef round steak': 0.5
# Jaccard_similarity between 'beef chuck steak' and 'beef sirloin steak': 0.5
# Jaccard_similarity between 'beef chuck steak' and 'beef skirt steak': 0.5
# Jaccard_similarity between 'beef chuck steak' and 'beef steak': 0.6666666666666666
# Jaccard_similarity between 'beef chuck steak' and 'beef tbone steak': 0.5
# Jaccard_similarity between 'beef chuck steak' and 'ground chuck ground beef': 0.5
# Jaccard_similarity between 'beef gravy' and 'gravy': 0.5
# Jaccard_similarity between 'beef roast' and 'beef roast pot roast': 0.6666666666666666
# Jaccard_similarity between 'beef roast' and 'beef roast ribeye': 0.6666666666666666
# Jaccard_similarity between 'beef roast' and 'beef roast rump': 0.6666666666666666
# Jaccard_similarity between 'beef roast' and 'roast beef': 1.0
# Jaccard_similarity between 'beef roast pot roast' and 'beef roast ribeye': 0.5
# Jaccard_similarity between 'beef roast pot roast' and 'beef roast rump': 0.5
# Jaccard_similarity between 'beef roast pot roast' and 'roast beef': 0.6666666666666666
# Jaccard_similarity between 'beef roast ribeye' and 'beef roast rump': 0.5
# Jaccard_similarity between 'beef roast ribeye' and 'roast beef': 0.6666666666666666
# Jaccard_similarity between 'beef roast rump' and 'moose rump roast': 0.5
# Jaccard_similarity between 'beef roast rump' and 'roast beef': 0.6666666666666666
# Jaccard_similarity between 'beef round steak' and 'beef sirloin steak': 0.5
# Jaccard_similarity between 'beef round steak' and 'beef skirt steak': 0.5
# Jaccard_similarity between 'beef round steak' and 'beef steak': 0.6666666666666666
# Jaccard_similarity between 'beef round steak' and 'beef tbone steak': 0.5
# Jaccard_similarity between 'beef sirloin steak' and 'beef sirloin tip': 0.5
# Jaccard_similarity between 'beef sirloin steak' and 'beef skirt steak': 0.5
# Jaccard_similarity between 'beef sirloin steak' and 'beef steak': 0.6666666666666666
# Jaccard_similarity between 'beef sirloin steak' and 'beef tbone steak': 0.5
# Jaccard_similarity between 'beef skirt steak' and 'beef steak': 0.6666666666666666
# Jaccard_similarity between 'beef skirt steak' and 'beef tbone steak': 0.5
# Jaccard_similarity between 'beef soup bones' and 'soup bones': 0.6666666666666666
# Jaccard_similarity between 'beef steak' and 'beef tbone steak': 0.6666666666666666
# Jaccard_similarity between 'beef stock' and 'stock': 0.5
# Jaccard_similarity between 'beef stock' and 'white stock': 0.5
# Jaccard_similarity between 'beef suet' and 'suet': 0.5
# Jaccard_similarity between 'beefmushroom freezer mix' and 'beeftomato freezer mix': 0.5
# Jaccard_similarity between 'beefsteak tomatoes' and 'green tomatoes': 0.5
# Jaccard_similarity between 'beefsteak tomatoes' and 'tomatoes': 0.5
# Jaccard_similarity between 'beefsteak tomatoes' and 'yellow tomatoes': 0.5
# Jaccard_similarity between 'beer' and 'beer batter': 0.5
# Jaccard_similarity between 'beer' and 'beer dark': 0.5
# Jaccard_similarity between 'beer' and 'beer lite': 0.5
# Jaccard_similarity between 'beer' and 'root beer': 0.5
# Jaccard_similarity between 'beer' and 'stout beer': 0.5
# Jaccard_similarity between 'beet juice' and 'juice': 0.5
# Jaccard_similarity between 'berries' and 'wheat berries': 0.5
# Jaccard_similarity between 'bibb lettuce' and 'lettuce': 0.5
# Jaccard_similarity between 'bibb lettuce' and 'red lettuce': 0.5
# Jaccard_similarity between 'biscuit dough' and 'dough': 0.5
# Jaccard_similarity between 'black bean sauce' and 'brown bean sauce': 1.0
# Jaccard_similarity between 'black bean sauce' and 'chili bean sauce': 0.6666666666666666
# Jaccard_similarity between 'black bean sauce' and 'hot bean sauce': 0.6666666666666666
# Jaccard_similarity between 'black bean sauce' and 'sauce': 0.5
# Jaccard_similarity between 'black bean sauce' and 'sweet bean sauce': 0.6666666666666666
# Jaccard_similarity between 'black bean sauce' and 'yellow bean sauce': 1.0
# Jaccard_similarity between 'black beans' and 'black gram beans': 0.5
# Jaccard_similarity between 'black beans' and 'brown beans': 1.0
# Jaccard_similarity between 'black beans' and 'chili beans': 0.5
# Jaccard_similarity between 'black beans' and 'cranberry beans': 0.5
# Jaccard_similarity between 'black beans' and 'fava beans': 0.5
# Jaccard_similarity between 'black beans' and 'green beans': 1.0
# Jaccard_similarity between 'black beans' and 'jelly beans': 0.5
# Jaccard_similarity between 'black beans' and 'lima beans': 0.5
# Jaccard_similarity between 'black beans' and 'long beans': 0.5
# Jaccard_similarity between 'black beans' and 'mung beans': 0.5
# Jaccard_similarity between 'black beans' and 'navy beans': 0.5
# Jaccard_similarity between 'black beans' and 'pinto beans': 0.5
# Jaccard_similarity between 'black beans' and 'red beans': 1.0
# Jaccard_similarity between 'black beans' and 'red kidney beans': 0.5
# Jaccard_similarity between 'black beans' and 'refried beans': 0.5
# Jaccard_similarity between 'black beans' and 'wax beans': 0.5
# Jaccard_similarity between 'black beans' and 'white beans': 1.0
# Jaccard_similarity between 'black beans' and 'white nothern beans': 0.5
# Jaccard_similarity between 'black currants' and 'currants': 1.0
# Jaccard_similarity between 'black currants' and 'red currants': 1.0
# Jaccard_similarity between 'black gram beans' and 'brown beans': 0.5
# Jaccard_similarity between 'black gram beans' and 'gram': 0.5
# Jaccard_similarity between 'black gram beans' and 'green beans': 0.5
# Jaccard_similarity between 'black gram beans' and 'red beans': 0.5
# Jaccard_similarity between 'black gram beans' and 'white beans': 0.5
# Jaccard_similarity between 'black licorice' and 'licorice': 1.0
# Jaccard_similarity between 'black mustard' and 'brown mustard': 1.0
# Jaccard_similarity between 'black mustard' and 'creole mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'dijon mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'dry mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'english mustard': 1.0
# Jaccard_similarity between 'black mustard' and 'french mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'honey mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'mustard greens': 0.5
# Jaccard_similarity between 'black mustard' and 'mustard oil': 0.5
# Jaccard_similarity between 'black mustard' and 'mustard seeds': 0.5
# Jaccard_similarity between 'black mustard' and 'mustard seeds black': 0.5
# Jaccard_similarity between 'black mustard' and 'prepared mustard': 0.5
# Jaccard_similarity between 'black mustard' and 'wholegrain mustard': 0.5
# Jaccard_similarity between 'black olives' and 'greek olives': 0.5
# Jaccard_similarity between 'black olives' and 'green olives': 1.0
# Jaccard_similarity between 'black olives' and 'kalamata olives': 0.5
# Jaccard_similarity between 'black olives' and 'olives': 1.0
# Jaccard_similarity between 'black pepper' and 'cayenne pepper': 0.5
# Jaccard_similarity between 'black pepper' and 'chile pepper': 0.5
# Jaccard_similarity between 'black pepper' and 'jalapeo pepper': 0.5
# Jaccard_similarity between 'black pepper' and 'lemon pepper': 0.5
# Jaccard_similarity between 'black pepper' and 'red pepper flakes': 0.5
# Jaccard_similarity between 'black pepper' and 'white pepper': 1.0
# Jaccard_similarity between 'black peppercorns' and 'green peppercorns': 1.0
# Jaccard_similarity between 'black peppercorns' and 'peppercorns': 1.0
# Jaccard_similarity between 'black peppercorns' and 'pink peppercorns': 0.5
# Jaccard_similarity between 'black peppercorns' and 'sichuan peppercorns': 0.5
# Jaccard_similarity between 'black peppercorns' and 'white peppercorns': 1.0
# Jaccard_similarity between 'blackeyed peas' and 'green peas': 0.5
# Jaccard_similarity between 'blue cheese' and 'boursin cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'brie cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'camembert cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'cheddar cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'cheese': 1.0
# Jaccard_similarity between 'blue cheese' and 'cheese cloth': 0.5
# Jaccard_similarity between 'blue cheese' and 'cheese tortellini': 0.5
# Jaccard_similarity between 'blue cheese' and 'colby cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'cotija cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'cottage cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'cream cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'curd cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'edam cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'emmentaler cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'farmers cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'feta cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'fontina cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'fortina cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'gorgonzola cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'gouda cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'gruyere cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'havarti cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'italian cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'jarlsberg cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'kasseri cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'kefalotiri cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'manchego cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'mascarpone cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'mexican cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'mizithra cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'mozzarella cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'muenster cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'neufchatel cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'old english cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'pecorino cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'provolone cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'ricotta cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'romano cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'roquefort cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'stilton cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'swiss cheese': 0.5
# Jaccard_similarity between 'blue cheese' and 'velveeta cheese': 0.5
# Jaccard_similarity between 'blueberry pie filling' and 'cherry pie filling': 0.5
# Jaccard_similarity between 'blueberry pie filling' and 'lemon pie filling': 0.5
# Jaccard_similarity between 'blueberry pie filling' and 'peach pie filling': 0.5
# Jaccard_similarity between 'boneless leg of lamb' and 'leg of lamb': 0.75
# Jaccard_similarity between 'bosc pears' and 'pears': 0.5
# Jaccard_similarity between 'boston lettuce' and 'lettuce': 0.5
# Jaccard_similarity between 'boston lettuce' and 'red lettuce': 0.5
# Jaccard_similarity between 'bouillon' and 'bouillon cubes': 0.5
# Jaccard_similarity between 'bouillon cubes' and 'chicken bouillon cubes': 0.6666666666666666
# Jaccard_similarity between 'bourbon' and 'bourbon whiskey': 0.5
# Jaccard_similarity between 'bourbon whiskey' and 'whiskey': 0.5
# Jaccard_similarity between 'boursin cheese' and 'cheese': 0.5
# Jaccard_similarity between 'bran flakes cereal' and 'oat bran cereal': 0.5
# Jaccard_similarity between 'bran flakes cereal' and 'raisin bran cereal': 0.5
# Jaccard_similarity between 'brazil nuts' and 'nuts': 0.5
# Jaccard_similarity between 'bread' and 'bread crumbs': 0.5
# Jaccard_similarity between 'bread' and 'bread dough': 0.5
# Jaccard_similarity between 'bread' and 'bread flour': 0.5
# Jaccard_similarity between 'bread' and 'bread italian': 0.5
# Jaccard_similarity between 'bread' and 'bread sticks': 0.5
# Jaccard_similarity between 'bread' and 'bread stuffing': 0.5
# Jaccard_similarity between 'bread' and 'bread wholegrain': 0.5
# Jaccard_similarity between 'bread' and 'crusty bread': 0.5
# Jaccard_similarity between 'bread' and 'french bread': 0.5
# Jaccard_similarity between 'bread' and 'garlic bread': 0.5
# Jaccard_similarity between 'bread' and 'pita bread': 0.5
# Jaccard_similarity between 'bread' and 'pumpernickel bread': 0.5
# Jaccard_similarity between 'bread' and 'rye bread': 0.5
# Jaccard_similarity between 'bread' and 'sourdough bread': 0.5
# Jaccard_similarity between 'bread' and 'white bread': 1.0
# Jaccard_similarity between 'bread crumbs' and 'bread crumbs whole wheat': 0.5
# Jaccard_similarity between 'bread crumbs' and 'seasoned dry bread crumbs': 0.5
# Jaccard_similarity between 'bread crumbs' and 'white bread': 0.5
# Jaccard_similarity between 'bread crumbs whole wheat' and 'pita bread whole wheat': 0.6
# Jaccard_similarity between 'bread crumbs whole wheat' and 'whole wheat bread': 0.75
# Jaccard_similarity between 'bread dough' and 'dough': 0.5
# Jaccard_similarity between 'bread dough' and 'white bread': 0.5
# Jaccard_similarity between 'bread flour' and 'white bread': 0.5
# Jaccard_similarity between 'bread french baguette' and 'french bread': 0.6666666666666666
# Jaccard_similarity between 'bread italian' and 'italian bread shell': 0.6666666666666666
# Jaccard_similarity between 'bread italian' and 'white bread': 0.5
# Jaccard_similarity between 'bread sticks' and 'white bread': 0.5
# Jaccard_similarity between 'bread stuffing' and 'stuffing': 0.5
# Jaccard_similarity between 'bread stuffing' and 'white bread': 0.5
# Jaccard_similarity between 'bread wholegrain' and 'white bread': 0.5
# Jaccard_similarity between 'breakfast sausage' and 'sausage': 0.5
# Jaccard_similarity between 'brewers yeast' and 'yeast extract': 0.5
# Jaccard_similarity between 'brie cheese' and 'cheese': 0.5
# Jaccard_similarity between 'brown bean sauce' and 'chili bean sauce': 0.6666666666666666
# Jaccard_similarity between 'brown bean sauce' and 'hot bean sauce': 0.6666666666666666
# Jaccard_similarity between 'brown bean sauce' and 'sauce': 0.5
# Jaccard_similarity between 'brown bean sauce' and 'sweet bean sauce': 0.6666666666666666
# Jaccard_similarity between 'brown bean sauce' and 'yellow bean sauce': 1.0
# Jaccard_similarity between 'brown beans' and 'chili beans': 0.5
# Jaccard_similarity between 'brown beans' and 'cranberry beans': 0.5
# Jaccard_similarity between 'brown beans' and 'fava beans': 0.5
# Jaccard_similarity between 'brown beans' and 'green beans': 1.0
# Jaccard_similarity between 'brown beans' and 'jelly beans': 0.5
# Jaccard_similarity between 'brown beans' and 'lima beans': 0.5
# Jaccard_similarity between 'brown beans' and 'long beans': 0.5
# Jaccard_similarity between 'brown beans' and 'mung beans': 0.5
# Jaccard_similarity between 'brown beans' and 'navy beans': 0.5
# Jaccard_similarity between 'brown beans' and 'pinto beans': 0.5
# Jaccard_similarity between 'brown beans' and 'red beans': 1.0
# Jaccard_similarity between 'brown beans' and 'red kidney beans': 0.5
# Jaccard_similarity between 'brown beans' and 'refried beans': 0.5
# Jaccard_similarity between 'brown beans' and 'wax beans': 0.5
# Jaccard_similarity between 'brown beans' and 'white beans': 1.0
# Jaccard_similarity between 'brown beans' and 'white nothern beans': 0.5
# Jaccard_similarity between 'brown lentils' and 'lentils': 1.0
# Jaccard_similarity between 'brown lentils' and 'lentils green': 1.0
# Jaccard_similarity between 'brown lentils' and 'lentils yellow': 1.0
# Jaccard_similarity between 'brown mustard' and 'creole mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'dijon mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'dry mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'english mustard': 1.0
# Jaccard_similarity between 'brown mustard' and 'french mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'honey mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'mustard greens': 0.5
# Jaccard_similarity between 'brown mustard' and 'mustard oil': 0.5
# Jaccard_similarity between 'brown mustard' and 'mustard seeds': 0.5
# Jaccard_similarity between 'brown mustard' and 'mustard seeds black': 0.5
# Jaccard_similarity between 'brown mustard' and 'prepared mustard': 0.5
# Jaccard_similarity between 'brown mustard' and 'wholegrain mustard': 0.5
# Jaccard_similarity between 'brown rice' and 'brown rice flour': 0.5
# Jaccard_similarity between 'brown rice' and 'brown rice syrup': 0.5
# Jaccard_similarity between 'brown rice' and 'brown rice vinegar': 0.5
# Jaccard_similarity between 'brown rice' and 'glutinous rice': 0.5
# Jaccard_similarity between 'brown rice' and 'jasmine rice': 0.5
# Jaccard_similarity between 'brown rice' and 'minute rice': 0.5
# Jaccard_similarity between 'brown rice' and 'rice': 1.0
# Jaccard_similarity between 'brown rice' and 'rice aromatic': 0.5
# Jaccard_similarity between 'brown rice' and 'rice cakes': 0.5
# Jaccard_similarity between 'brown rice' and 'rice flour': 0.5
# Jaccard_similarity between 'brown rice' and 'rice milk': 0.5
# Jaccard_similarity between 'brown rice' and 'rice noodles': 0.5
# Jaccard_similarity between 'brown rice' and 'rice pilaf': 0.5
# Jaccard_similarity between 'brown rice' and 'rice sticks': 0.5
# Jaccard_similarity between 'brown rice' and 'rice syrup': 0.5
# Jaccard_similarity between 'brown rice' and 'rice vermicelli': 0.5
# Jaccard_similarity between 'brown rice' and 'rice vinegar': 0.5
# Jaccard_similarity between 'brown rice' and 'rice wine': 0.5
# Jaccard_similarity between 'brown rice' and 'spanish brown rice': 0.5
# Jaccard_similarity between 'brown rice' and 'sushi rice': 0.5
# Jaccard_similarity between 'brown rice' and 'wild rice': 0.5
# Jaccard_similarity between 'brown rice flour' and 'rice': 0.5
# Jaccard_similarity between 'brown rice flour' and 'rice flour': 1.0
# Jaccard_similarity between 'brown rice syrup' and 'rice': 0.5
# Jaccard_similarity between 'brown rice syrup' and 'rice syrup': 1.0
# Jaccard_similarity between 'brown rice syrup' and 'syrup': 0.5
# Jaccard_similarity between 'brown rice vinegar' and 'japanese rice vinegar': 0.6666666666666666
# Jaccard_similarity between 'brown rice vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'brown rice vinegar' and 'rice': 0.5
# Jaccard_similarity between 'brown rice vinegar' and 'rice vinegar': 1.0
# Jaccard_similarity between 'brown rice vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'brown rice vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'brown sugar' and 'brown sugar dark': 0.5
# Jaccard_similarity between 'brown sugar' and 'brown sugar light': 0.5
# Jaccard_similarity between 'brown sugar' and 'cinnamon sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'coconut sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'date sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'demerara sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'palm sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'powdered sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'raw sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'rock sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'sugar': 1.0
# Jaccard_similarity between 'brown sugar' and 'sugar cane': 0.5
# Jaccard_similarity between 'brown sugar' and 'sugar crystals': 0.5
# Jaccard_similarity between 'brown sugar' and 'sugar substitute': 0.5
# Jaccard_similarity between 'brown sugar' and 'sugar superfine': 0.5
# Jaccard_similarity between 'brown sugar' and 'turbinado sugar': 0.5
# Jaccard_similarity between 'brown sugar' and 'vanilla sugar': 0.5
# Jaccard_similarity between 'brown sugar dark' and 'sugar': 0.5
# Jaccard_similarity between 'brown sugar light' and 'sugar': 0.5
# Jaccard_similarity between 'browning sauce' and 'sauce': 0.5
# Jaccard_similarity between 'buffalo meat' and 'meat': 0.5
# Jaccard_similarity between 'buffalo meat' and 'meat extract': 0.5
# Jaccard_similarity between 'buns' and 'hamburger buns': 0.5
# Jaccard_similarity between 'burgundy wine' and 'red burgundy wine': 1.0
# Jaccard_similarity between 'burgundy wine' and 'red wine': 0.5
# Jaccard_similarity between 'burgundy wine' and 'white wine': 0.5
# Jaccard_similarity between 'burgundy wine' and 'wine': 0.5
# Jaccard_similarity between 'butter' and 'butter buds': 0.5
# Jaccard_similarity between 'butter' and 'cashew butter': 0.5
# Jaccard_similarity between 'butter' and 'peanut butter': 0.5
# Jaccard_similarity between 'butter cream frosting' and 'cream cheese frosting': 0.5
# Jaccard_similarity between 'buttermilk' and 'buttermilk biscuits': 0.5
# Jaccard_similarity between 'buttermilk' and 'buttermilk mayonnaise': 0.5
# Jaccard_similarity between 'buttermilk baking mix' and 'buttermilk pancake mix': 0.5
# Jaccard_similarity between 'buttermilk mayonnaise' and 'mayonnaise': 0.5
# Jaccard_similarity between 'buttermilk pancake mix' and 'pancake mix': 0.6666666666666666
# Jaccard_similarity between 'cabbage' and 'cabbage leaves': 0.5
# Jaccard_similarity between 'cabbage' and 'red cabbage': 1.0
# Jaccard_similarity between 'cabbage' and 'red cabbage leaves': 0.5
# Jaccard_similarity between 'cabbage' and 'savoy cabbage': 0.5
# Jaccard_similarity between 'cabbage leaves' and 'napa cabbage leaves': 0.6666666666666666
# Jaccard_similarity between 'cabbage leaves' and 'red cabbage': 0.5
# Jaccard_similarity between 'cabbage leaves' and 'red cabbage leaves': 1.0
# Jaccard_similarity between 'cajun seasoning' and 'seasoning': 0.5
# Jaccard_similarity between 'cake' and 'cake crumbs': 0.5
# Jaccard_similarity between 'cake' and 'cake flour': 0.5
# Jaccard_similarity between 'cake' and 'cake meal': 0.5
# Jaccard_similarity between 'cake' and 'cake mix': 0.5
# Jaccard_similarity between 'cake' and 'cake mix white': 0.5
# Jaccard_similarity between 'cake' and 'cake mix yellow': 0.5
# Jaccard_similarity between 'cake' and 'pound cake': 0.5
# Jaccard_similarity between 'cake' and 'sponge cake': 0.5
# Jaccard_similarity between 'cake meal' and 'meal': 0.5
# Jaccard_similarity between 'cake mix' and 'cake mix chocolate': 0.6666666666666666
# Jaccard_similarity between 'cake mix' and 'cake mix devils food': 0.5
# Jaccard_similarity between 'cake mix' and 'cake mix german chocolate': 0.5
# Jaccard_similarity between 'cake mix' and 'cake mix lemon': 0.6666666666666666
# Jaccard_similarity between 'cake mix' and 'cake mix orange': 0.6666666666666666
# Jaccard_similarity between 'cake mix' and 'cake mix white': 1.0
# Jaccard_similarity between 'cake mix' and 'cake mix yellow': 1.0
# Jaccard_similarity between 'cake mix chocolate' and 'cake mix german chocolate': 0.75
# Jaccard_similarity between 'cake mix chocolate' and 'cake mix lemon': 0.5
# Jaccard_similarity between 'cake mix chocolate' and 'cake mix orange': 0.5
# Jaccard_similarity between 'cake mix chocolate' and 'cake mix white': 0.6666666666666666
# Jaccard_similarity between 'cake mix chocolate' and 'cake mix yellow': 0.6666666666666666
# Jaccard_similarity between 'cake mix chocolate' and 'chocolate milk mix': 0.5
# Jaccard_similarity between 'cake mix devils food' and 'cake mix white': 0.5
# Jaccard_similarity between 'cake mix devils food' and 'cake mix yellow': 0.5
# Jaccard_similarity between 'cake mix german chocolate' and 'cake mix white': 0.5
# Jaccard_similarity between 'cake mix german chocolate' and 'cake mix yellow': 0.5
# Jaccard_similarity between 'cake mix lemon' and 'cake mix orange': 0.5
# Jaccard_similarity between 'cake mix lemon' and 'cake mix white': 0.6666666666666666
# Jaccard_similarity between 'cake mix lemon' and 'cake mix yellow': 0.6666666666666666
# Jaccard_similarity between 'cake mix orange' and 'cake mix white': 0.6666666666666666
# Jaccard_similarity between 'cake mix orange' and 'cake mix yellow': 0.6666666666666666
# Jaccard_similarity between 'cake mix white' and 'cake mix yellow': 1.0
# Jaccard_similarity between 'camembert cheese' and 'cheese': 0.5
# Jaccard_similarity between 'candied cherries' and 'cherries': 0.5
# Jaccard_similarity between 'candied citron' and 'citron': 0.5
# Jaccard_similarity between 'candied fruit' and 'fruit': 0.5
# Jaccard_similarity between 'candied orange peel' and 'candied peel': 0.6666666666666666
# Jaccard_similarity between 'candied orange peel' and 'mixed candied peel': 0.5
# Jaccard_similarity between 'candied peel' and 'mixed candied peel': 0.6666666666666666
# Jaccard_similarity between 'candied pineapple' and 'pineapple': 0.5
# Jaccard_similarity between 'candies' and 'chocolate candies': 0.5
# Jaccard_similarity between 'candy' and 'candy canes': 0.5
# Jaccard_similarity between 'candy' and 'candy corn': 0.5
# Jaccard_similarity between 'candy coated chocolate pieces' and 'chocolate pieces': 0.5
# Jaccard_similarity between 'candy corn' and 'corn': 0.5
# Jaccard_similarity between 'candy corn' and 'yellow corn': 0.5
# Jaccard_similarity between 'canned ham' and 'ham': 0.5
# Jaccard_similarity between 'canned salmon' and 'salmon': 0.5
# Jaccard_similarity between 'canning salt' and 'salt': 0.5
# Jaccard_similarity between 'cappuccino flavoring' and 'flavoring': 0.5
# Jaccard_similarity between 'caramel ice cream topping' and 'ice cream': 0.5
# Jaccard_similarity between 'caramel sauce' and 'sauce': 0.5
# Jaccard_similarity between 'caramel syrup' and 'syrup': 0.5
# Jaccard_similarity between 'carnation basic muffin mix' and 'muffin mix': 0.5
# Jaccard_similarity between 'carrot juice' and 'juice': 0.5
# Jaccard_similarity between 'cashew nuts' and 'nuts': 0.5
# Jaccard_similarity between 'catfish' and 'catfish fillets': 0.5
# Jaccard_similarity between 'cayenne pepper' and 'cayenne pepper sauce': 0.6666666666666666
# Jaccard_similarity between 'cayenne pepper' and 'salt and cayenne pepper': 0.5
# Jaccard_similarity between 'cayenne pepper' and 'white pepper': 0.5
# Jaccard_similarity between 'cayenne pepper sauce' and 'red hot pepper sauce': 0.5
# Jaccard_similarity between 'celery' and 'celery flakes': 0.5
# Jaccard_similarity between 'celery' and 'celery heart': 0.5
# Jaccard_similarity between 'celery' and 'celery leaves': 0.5
# Jaccard_similarity between 'celery' and 'celery salt': 0.5
# Jaccard_similarity between 'celery' and 'celery seeds': 0.5
# Jaccard_similarity between 'celery' and 'celery stalks': 0.5
# Jaccard_similarity between 'celery salt' and 'salt': 0.5
# Jaccard_similarity between 'cellophane noodles' and 'noodles': 0.5
# Jaccard_similarity between 'cereal' and 'cereal multigrain': 0.5
# Jaccard_similarity between 'cereal' and 'cheerios cereal': 0.5
# Jaccard_similarity between 'champagne' and 'champagne vinegar': 0.5
# Jaccard_similarity between 'champagne vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'champagne vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'champagne vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'chapatis' and 'wholewheat chapatis': 0.5
# Jaccard_similarity between 'chardonnary vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'chardonnary vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'chardonnary vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'cheddar cheese' and 'cheddar cheese medium': 0.6666666666666666
# Jaccard_similarity between 'cheddar cheese' and 'cheddar cheese mild': 0.6666666666666666
# Jaccard_similarity between 'cheddar cheese' and 'cheddar cheese reducedfat': 0.6666666666666666
# Jaccard_similarity between 'cheddar cheese' and 'cheese': 0.5
# Jaccard_similarity between 'cheddar cheese' and 'sharp cheddar cheese spread': 0.5
# Jaccard_similarity between 'cheddar cheese medium' and 'cheddar cheese mild': 0.5
# Jaccard_similarity between 'cheddar cheese medium' and 'cheddar cheese reducedfat': 0.5
# Jaccard_similarity between 'cheddar cheese mild' and 'cheddar cheese reducedfat': 0.5
# Jaccard_similarity between 'cheddar cheese reducedfat' and 'cream cheese reducedfat': 0.5
# Jaccard_similarity between 'cheddar cheese very old sharp' and 'sharp cheddar cheese spread': 0.5
# Jaccard_similarity between 'cheese' and 'cheese cloth': 0.5
# Jaccard_similarity between 'cheese' and 'cheese tortellini': 0.5
# Jaccard_similarity between 'cheese' and 'colby cheese': 0.5
# Jaccard_similarity between 'cheese' and 'cotija cheese': 0.5
# Jaccard_similarity between 'cheese' and 'cottage cheese': 0.5
# Jaccard_similarity between 'cheese' and 'cream cheese': 0.5
# Jaccard_similarity between 'cheese' and 'curd cheese': 0.5
# Jaccard_similarity between 'cheese' and 'edam cheese': 0.5
# Jaccard_similarity between 'cheese' and 'emmentaler cheese': 0.5
# Jaccard_similarity between 'cheese' and 'farmers cheese': 0.5
# Jaccard_similarity between 'cheese' and 'feta cheese': 0.5
# Jaccard_similarity between 'cheese' and 'fontina cheese': 0.5
# Jaccard_similarity between 'cheese' and 'fortina cheese': 0.5
# Jaccard_similarity between 'cheese' and 'gorgonzola cheese': 0.5
# Jaccard_similarity between 'cheese' and 'gouda cheese': 0.5
# Jaccard_similarity between 'cheese' and 'gruyere cheese': 0.5
# Jaccard_similarity between 'cheese' and 'havarti cheese': 0.5
# Jaccard_similarity between 'cheese' and 'italian cheese': 0.5
# Jaccard_similarity between 'cheese' and 'jarlsberg cheese': 0.5
# Jaccard_similarity between 'cheese' and 'kasseri cheese': 0.5
# Jaccard_similarity between 'cheese' and 'kefalotiri cheese': 0.5
# Jaccard_similarity between 'cheese' and 'manchego cheese': 0.5
# Jaccard_similarity between 'cheese' and 'mascarpone cheese': 0.5
# Jaccard_similarity between 'cheese' and 'mexican cheese': 0.5
# Jaccard_similarity between 'cheese' and 'mizithra cheese': 0.5
# Jaccard_similarity between 'cheese' and 'mozzarella cheese': 0.5
# Jaccard_similarity between 'cheese' and 'muenster cheese': 0.5
# Jaccard_similarity between 'cheese' and 'neufchatel cheese': 0.5
# Jaccard_similarity between 'cheese' and 'old english cheese': 0.5
# Jaccard_similarity between 'cheese' and 'pecorino cheese': 0.5
# Jaccard_similarity between 'cheese' and 'provolone cheese': 0.5
# Jaccard_similarity between 'cheese' and 'ricotta cheese': 0.5
# Jaccard_similarity between 'cheese' and 'romano cheese': 0.5
# Jaccard_similarity between 'cheese' and 'roquefort cheese': 0.5
# Jaccard_similarity between 'cheese' and 'stilton cheese': 0.5
# Jaccard_similarity between 'cheese' and 'swiss cheese': 0.5
# Jaccard_similarity between 'cheese' and 'velveeta cheese': 0.5
# Jaccard_similarity between 'cheese tortellini' and 'tortellini': 0.5
# Jaccard_similarity between 'cherries' and 'maraschino cherries': 0.5
# Jaccard_similarity between 'cherries' and 'sour cherries': 0.5
# Jaccard_similarity between 'cherry juice' and 'juice': 0.5
# Jaccard_similarity between 'cherry pie filling' and 'lemon pie filling': 0.5
# Jaccard_similarity between 'cherry pie filling' and 'peach pie filling': 0.5
# Jaccard_similarity between 'cherry preserves' and 'preserves': 0.5
# Jaccard_similarity between 'cherry tomatoes' and 'green tomatoes': 0.5
# Jaccard_similarity between 'cherry tomatoes' and 'tomatoes': 0.5
# Jaccard_similarity between 'cherry tomatoes' and 'yellow tomatoes': 0.5
# Jaccard_similarity between 'chestnut honey' and 'honey': 0.5
# Jaccard_similarity between 'chestnuts' and 'water chestnuts': 0.5
# Jaccard_similarity between 'chicken' and 'chicken breasts': 0.5
# Jaccard_similarity between 'chicken' and 'chicken broth': 0.5
# Jaccard_similarity between 'chicken' and 'chicken cutlets': 0.5
# Jaccard_similarity between 'chicken' and 'chicken drumettes': 0.5
# Jaccard_similarity between 'chicken' and 'chicken drumsticks': 0.5
# Jaccard_similarity between 'chicken' and 'chicken gravy': 0.5
# Jaccard_similarity between 'chicken' and 'chicken legs': 0.5
# Jaccard_similarity between 'chicken' and 'chicken livers': 0.5
# Jaccard_similarity between 'chicken' and 'chicken pieces': 0.5
# Jaccard_similarity between 'chicken' and 'chicken sausage': 0.5
# Jaccard_similarity between 'chicken' and 'chicken tenders': 0.5
# Jaccard_similarity between 'chicken' and 'chicken wings': 0.5
# Jaccard_similarity between 'chicken' and 'ground chicken': 0.5
# Jaccard_similarity between 'chicken' and 'soup chicken': 0.5
# Jaccard_similarity between 'chicken' and 'whole chicken': 0.5
# Jaccard_similarity between 'chicken breast halves boneless skinless' and 'chicken breast halves boneless skinon': 0.6666666666666666
# Jaccard_similarity between 'chicken breast halves boneless skinless' and 'chicken thighs boneless skinless': 0.5
# Jaccard_similarity between 'chicken broth' and 'chicken broth low salt': 0.5
# Jaccard_similarity between 'chicken gravy' and 'gravy': 0.5
# Jaccard_similarity between 'chicken sausage' and 'sausage': 0.5
# Jaccard_similarity between 'chickpea liquid' and 'liquid': 0.5
# Jaccard_similarity between 'chile pepper' and 'white pepper': 0.5
# Jaccard_similarity between 'chili and garlic paste' and 'garlic and giner paste': 0.6
# Jaccard_similarity between 'chili and garlic paste' and 'garlic paste': 0.5
# Jaccard_similarity between 'chili bean sauce' and 'chili garlic sauce': 0.5
# Jaccard_similarity between 'chili bean sauce' and 'chili sauce': 0.6666666666666666
# Jaccard_similarity between 'chili bean sauce' and 'hot bean sauce': 0.5
# Jaccard_similarity between 'chili bean sauce' and 'red chili sauce': 0.6666666666666666
# Jaccard_similarity between 'chili bean sauce' and 'sweet bean sauce': 0.5
# Jaccard_similarity between 'chili bean sauce' and 'yellow bean sauce': 0.6666666666666666
# Jaccard_similarity between 'chili beans' and 'green beans': 0.5
# Jaccard_similarity between 'chili beans' and 'red beans': 0.5
# Jaccard_similarity between 'chili beans' and 'white beans': 0.5
# Jaccard_similarity between 'chili garlic sauce' and 'chili sauce': 0.6666666666666666
# Jaccard_similarity between 'chili garlic sauce' and 'garlic sauce': 0.6666666666666666
# Jaccard_similarity between 'chili garlic sauce' and 'red chili sauce': 0.6666666666666666
# Jaccard_similarity between 'chili pepper flakes' and 'hawaiian chili pepper': 0.5
# Jaccard_similarity between 'chili pepper flakes' and 'red pepper flakes': 0.6666666666666666
# Jaccard_similarity between 'chili sauce' and 'red chili sauce': 1.0
# Jaccard_similarity between 'chili sauce' and 'sauce': 0.5
# Jaccard_similarity between 'chili seasoning mix' and 'seasoning mix': 0.6666666666666666
# Jaccard_similarity between 'chili seasoning mix' and 'taco seasoning mix': 0.5
# Jaccard_similarity between 'china black tea leaves' and 'tea leaves': 0.6666666666666666
# Jaccard_similarity between 'chinese black vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'chinese black vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'chinese black vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'chinkiang vinegar' and 'red vinegar': 0.5
# Jaccard_similarity between 'chinkiang vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'chinkiang vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'chipotle chili peppers' and 'green chili peppers': 0.6666666666666666
# Jaccard_similarity between 'chipotle chili peppers' and 'habanero chili peppers': 0.5
# Jaccard_similarity between 'chipotle chili peppers' and 'hot chili peppers': 0.5
# Jaccard_similarity between 'chipotle chili peppers' and 'red chili peppers': 0.6666666666666666
# Jaccard_similarity between 'chipotle salsa' and 'green salsa': 0.5
# Jaccard_similarity between 'chipotle salsa' and 'salsa': 0.5
# Jaccard_similarity between 'chipotle sauce' and 'sauce': 0.5
# Jaccard_similarity between 'chives' and 'garlic chives': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate bars': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate bittersweet': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate candies': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate chips': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate chunks': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate cookies': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate curls': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate extract': 1.0
# Jaccard_similarity between 'chocolate' and 'chocolate frosting': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate ganache': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate kisses': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate mints': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate pieces': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate pudding': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate sauce': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate sprinkles': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate sweet': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate syrup': 0.5
# Jaccard_similarity between 'chocolate' and 'chocolate wafers': 0.5
# Jaccard_similarity between 'chocolate' and 'cooking chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'dark chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'milk chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'milkcote chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'semisweet chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'unsweetened chocolate': 0.5
# Jaccard_similarity between 'chocolate' and 'white chocolate': 1.0
# Jaccard_similarity between 'chocolate' and 'white chocolate chips': 0.5
# Jaccard_similarity between 'chocolate bars' and 'chocolate extract': 0.5
# Jaccard_similarity between 'chocolate bars' and 'milk chocolate bars': 0.6666666666666666
# Jaccard_similarity between 'chocolate bars' and 'white chocolate': 0.5
# Jaccard_similarity between 'chocolate bittersweet' and 'chocolate extract': 0.5
# Jaccard_similarity between 'chocolate bittersweet' and 'white chocolate': 0.5
# Jaccard_similarity between 'chocolate candies' and 'chocolate extract': 0.5
# Jaccard_similarity between 'chocolate candies' and 'white chocolate': 0.5
# Jaccard_similarity between 'chocolate chips' and 'chocolate chips semisweet': 0.6666666666666666
# ...
# Jaccard_similarity between 'salad dressing creamy' and 'salad dressing french': 0.5
# Jaccard_similarity between 'salad dressing creamy' and 'salad dressing italian': 0.5
# Jaccard_similarity between 'salad dressing creamy' and 'salad dressing lowfat': 0.5
# Jaccard_similarity between 'salad dressing creamy' and 'salad dressing russian': 0.5
# Jaccard_similarity between 'salad dressing creamy' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salad dressing creamy ranch' and 'salad dressing mix ranch': 0.6
# Jaccard_similarity between 'salad dressing fatfree' and 'salad dressing french': 0.5
# Jaccard_similarity between 'salad dressing fatfree' and 'salad dressing italian': 0.5
# Jaccard_similarity between 'salad dressing fatfree' and 'salad dressing lowfat': 0.5
# Jaccard_similarity between 'salad dressing fatfree' and 'salad dressing russian': 0.5
# Jaccard_similarity between 'salad dressing fatfree' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salad dressing french' and 'salad dressing italian': 0.5
# Jaccard_similarity between 'salad dressing french' and 'salad dressing lowfat': 0.5
# Jaccard_similarity between 'salad dressing french' and 'salad dressing russian': 0.5
# Jaccard_similarity between 'salad dressing french' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salad dressing italian' and 'salad dressing italian lowfat': 0.75
# Jaccard_similarity between 'salad dressing italian' and 'salad dressing lowfat': 0.5
# Jaccard_similarity between 'salad dressing italian' and 'salad dressing mix italian': 0.75
# Jaccard_similarity between 'salad dressing italian' and 'salad dressing russian': 0.5
# Jaccard_similarity between 'salad dressing italian' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salad dressing italian lowfat' and 'salad dressing lowfat': 0.75
# Jaccard_similarity between 'salad dressing italian lowfat' and 'salad dressing mix italian': 0.6
# Jaccard_similarity between 'salad dressing lowfat' and 'salad dressing russian': 0.5
# Jaccard_similarity between 'salad dressing lowfat' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salad dressing mix italian' and 'salad dressing mix ranch': 0.6
# Jaccard_similarity between 'salad dressing russian' and 'salad dressing vinaigrette': 0.5
# Jaccard_similarity between 'salmon' and 'salmon fillets': 0.5
# Jaccard_similarity between 'salmon' and 'salmon steaks': 0.5
# Jaccard_similarity between 'salmon' and 'smoked salmon': 0.5
# Jaccard_similarity between 'salsa' and 'salsa verde': 0.5
# Jaccard_similarity between 'salt' and 'salt pork': 0.5
# Jaccard_similarity between 'salt' and 'salt substitute': 0.5
# Jaccard_similarity between 'salt' and 'sea salt': 0.5
# Jaccard_similarity between 'salt' and 'seasoned salt': 0.5
# Jaccard_similarity between 'salt and black pepper' and 'salt and cayenne pepper': 0.75
# Jaccard_similarity between 'salt and black pepper' and 'salt and white pepper': 1.0
# Jaccard_similarity between 'salt and cayenne pepper' and 'salt and white pepper': 0.75
# Jaccard_similarity between 'saltfree seasoning' and 'seasoning': 0.5
# Jaccard_similarity between 'sauce' and 'spaghetti sauce': 0.5
# Jaccard_similarity between 'sauce' and 'steak sauce': 0.5
# Jaccard_similarity between 'sauce' and 'taco sauce': 0.5
# Jaccard_similarity between 'sauce' and 'tartar sauce': 0.5
# Jaccard_similarity between 'sauce' and 'teriyaki sauce': 0.5
# Jaccard_similarity between 'sauce' and 'tomato sauce': 0.5
# Jaccard_similarity between 'sauce' and 'worcestershire sauce': 0.5
# Jaccard_similarity between 'sauce' and 'yellow bean sauce': 0.5
# Jaccard_similarity between 'sausage' and 'sausage bulk': 0.5
# Jaccard_similarity between 'sausage' and 'sausage casing': 0.5
# Jaccard_similarity between 'sausage' and 'sausage links': 0.5
# Jaccard_similarity between 'sausage' and 'sausage meat': 0.5
# Jaccard_similarity between 'sausage' and 'smoked sausage': 0.5
# Jaccard_similarity between 'sausage' and 'turkey sausage': 0.5
# Jaccard_similarity between 'sauterne' and 'sauterne wine': 0.5
# Jaccard_similarity between 'sauterne wine' and 'white wine': 0.5
# Jaccard_similarity between 'sauterne wine' and 'wine': 0.5
# Jaccard_similarity between 'scallops' and 'sea scallops': 0.5
# Jaccard_similarity between 'scotch whiskey' and 'whiskey': 0.5
# Jaccard_similarity between 'seafood stock' and 'stock': 0.5
# Jaccard_similarity between 'seafood stock' and 'white stock': 0.5
# Jaccard_similarity between 'seasoning' and 'seasoning mix': 0.5
# Jaccard_similarity between 'seasoning' and 'steak seasoning': 0.5
# Jaccard_similarity between 'seasoning mix' and 'taco seasoning mix': 0.6666666666666666
# Jaccard_similarity between 'semisweet chocolate' and 'white chocolate': 0.5
# Jaccard_similarity between 'shaoxing wine' and 'white wine': 0.5
# Jaccard_similarity between 'shaoxing wine' and 'wine': 0.5
# Jaccard_similarity between 'sherry' and 'sherry vinegar': 0.5
# Jaccard_similarity between 'sherry' and 'sherry wine': 0.5
# Jaccard_similarity between 'sherry vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'sherry vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'sherry wine' and 'white wine': 0.5
# Jaccard_similarity between 'sherry wine' and 'wine': 0.5
# Jaccard_similarity between 'shredded wheat cereal' and 'wheat chex cereal': 0.5
# Jaccard_similarity between 'shrimp' and 'shrimp paste': 0.5
# Jaccard_similarity between 'shrimp' and 'shrimp puffs': 0.5
# Jaccard_similarity between 'sichuan peppercorns' and 'white peppercorns': 0.5
# Jaccard_similarity between 'silken tofu' and 'tofu': 0.5
# Jaccard_similarity between 'smoked ham' and 'smoked ham shank': 0.6666666666666666
# Jaccard_similarity between 'smoked mozzarella cheese' and 'soy cheese mozzarella': 0.5
# Jaccard_similarity between 'smoked turkey breast' and 'turkey breast': 0.6666666666666666
# Jaccard_similarity between 'smoked turkey breast' and 'turkey breast fillets': 0.5
# Jaccard_similarity between 'smoked whitefish' and 'whitefish': 0.5
# Jaccard_similarity between 'soda water' and 'water': 0.5
# Jaccard_similarity between 'soup chicken' and 'soup cream of chicken': 0.5
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of broccoli': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of celery': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of cheddar': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of chicken': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of onion': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of asparagus' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of celery': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of cheddar': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of chicken': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of onion': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of broccoli' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of celery' and 'soup cream of cheddar': 0.6
# Jaccard_similarity between 'soup cream of celery' and 'soup cream of chicken': 0.6
# Jaccard_similarity between 'soup cream of celery' and 'soup cream of onion': 0.6
# Jaccard_similarity between 'soup cream of celery' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of celery' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of cheddar' and 'soup cream of chicken': 0.6
# Jaccard_similarity between 'soup cream of cheddar' and 'soup cream of onion': 0.6
# Jaccard_similarity between 'soup cream of cheddar' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of cheddar' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of chicken' and 'soup cream of onion': 0.6
# Jaccard_similarity between 'soup cream of chicken' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of chicken' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of onion' and 'soup cream of potato': 0.6
# Jaccard_similarity between 'soup cream of onion' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of potato' and 'soup cream of tomato': 0.6
# Jaccard_similarity between 'soup cream of tomato' and 'tomato soup': 0.5
# Jaccard_similarity between 'soup mix chicken noodle dry' and 'soup mix vegetable dry': 0.5
# Jaccard_similarity between 'soup mix chicken noodle dry' and 'vegetable soup mix dry': 0.5
# Jaccard_similarity between 'soup mix vegetable dry' and 'soup vegetable mix': 0.75
# Jaccard_similarity between 'soup mix vegetable dry' and 'vegetable soup mix dry': 1.0
# Jaccard_similarity between 'soup noodles' and 'soup ramen noodles': 0.6666666666666666
# Jaccard_similarity between 'soup vegetable mix' and 'vegetable soup mix dry': 0.75
# Jaccard_similarity between 'sour cream' and 'sour cream light': 0.6666666666666666
# Jaccard_similarity between 'sour cream' and 'sour cream nonfat': 0.6666666666666666
# Jaccard_similarity between 'sour cream light' and 'sour cream nonfat': 0.5
# Jaccard_similarity between 'sourdough' and 'sourdough bread': 0.5
# Jaccard_similarity between 'sourdough' and 'sourdough starter': 0.5
# Jaccard_similarity between 'sourdough bread' and 'white bread': 0.5
# Jaccard_similarity between 'sourdough starter' and 'starter': 0.5
# Jaccard_similarity between 'soy' and 'soy flour': 0.5
# Jaccard_similarity between 'soy' and 'soy milk': 0.5
# Jaccard_similarity between 'soy' and 'soy oil': 0.5
# Jaccard_similarity between 'soy' and 'soy yogurt': 0.5
# Jaccard_similarity between 'soy sauce dark' and 'soy sauce light': 0.5
# Jaccard_similarity between 'soy sauce dark' and 'soy sauce tamari': 0.5
# Jaccard_similarity between 'soy sauce light' and 'soy sauce tamari': 0.5
# Jaccard_similarity between 'soy yogurt' and 'yogurt': 0.5
# Jaccard_similarity between 'spaghetti' and 'spaghetti sauce': 0.5
# Jaccard_similarity between 'spaghetti' and 'spaghetti squash': 0.5
# Jaccard_similarity between 'spinach' and 'spinach dip': 0.5
# Jaccard_similarity between 'spinach' and 'spinach frozen': 0.5
# Jaccard_similarity between 'split peas' and 'yellow split peas': 1.0
# Jaccard_similarity between 'sponge' and 'sponge cake': 0.5
# Jaccard_similarity between 'stock' and 'turkey stock': 0.5
# Jaccard_similarity between 'stock' and 'vegetable stock': 0.5
# Jaccard_similarity between 'stock' and 'white stock': 1.0
# Jaccard_similarity between 'strawberry extract' and 'strawberry glaze': 0.5
# Jaccard_similarity between 'strawberry extract' and 'strawberry jam': 0.5
# Jaccard_similarity between 'strawberry extract' and 'strawberry jelly': 0.5
# Jaccard_similarity between 'strawberry extract' and 'strawberry preserves': 0.5
# Jaccard_similarity between 'strawberry extract' and 'strawberry soda': 0.5
# Jaccard_similarity between 'strawberry ice cream' and 'vanilla ice cream': 0.5
# Jaccard_similarity between 'stuffing' and 'stuffing mix': 0.5
# Jaccard_similarity between 'sugar' and 'sugar cane': 0.5
# Jaccard_similarity between 'sugar' and 'sugar crystals': 0.5
# Jaccard_similarity between 'sugar' and 'sugar substitute': 0.5
# Jaccard_similarity between 'sugar' and 'sugar superfine': 0.5
# Jaccard_similarity between 'sugar' and 'turbinado sugar': 0.5
# Jaccard_similarity between 'sugar' and 'vanilla sugar': 0.5
# Jaccard_similarity between 'sundried tomatoes' and 'tomatoes': 0.5
# Jaccard_similarity between 'sundried tomatoes' and 'yellow tomatoes': 0.5
# Jaccard_similarity between 'sweet bean sauce' and 'yellow bean sauce': 0.6666666666666666
# Jaccard_similarity between 'sweet bell peppers' and 'sweet red bell peppers': 1.0
# Jaccard_similarity between 'sweet bell peppers' and 'sweet yellow bell peppers': 1.0
# Jaccard_similarity between 'sweet red bell peppers' and 'sweet yellow bell peppers': 1.0
# Jaccard_similarity between 'tamarind' and 'tamarind juice': 0.5
# Jaccard_similarity between 'tapioca' and 'tapioca flour': 0.5
# Jaccard_similarity between 'tapioca' and 'tapioca quickcooking': 0.5
# Jaccard_similarity between 'tarragon vinegar' and 'vinegar': 0.5
# Jaccard_similarity between 'tarragon vinegar' and 'white vinegar': 0.5
# Jaccard_similarity between 'tea' and 'tea bags': 0.5
# Jaccard_similarity between 'tea' and 'tea leaves': 0.5
# Jaccard_similarity between 'thai chile sauce' and 'thai peanut sauce': 0.5
# Jaccard_similarity between 'thyme' and 'thyme sprigs': 0.5
# Jaccard_similarity between 'tofu' and 'tofu cakes': 0.5
# Jaccard_similarity between 'tomatoes' and 'yellow tomatoes': 1.0
# Jaccard_similarity between 'trout' and 'trout fillets': 0.5
# Jaccard_similarity between 'tuna' and 'tuna fish': 0.5
# Jaccard_similarity between 'tuna' and 'tuna steaks': 0.5
# Jaccard_similarity between 'turkey' and 'turkey bacon': 0.5
# Jaccard_similarity between 'turkey' and 'turkey breast': 0.5
# Jaccard_similarity between 'turkey' and 'turkey broth': 0.5
# Jaccard_similarity between 'turkey' and 'turkey ham': 0.5
# Jaccard_similarity between 'turkey' and 'turkey legs': 0.5
# Jaccard_similarity between 'turkey' and 'turkey liver': 0.5
# Jaccard_similarity between 'turkey' and 'turkey meat': 0.5
# Jaccard_similarity between 'turkey' and 'turkey sausage': 0.5
# Jaccard_similarity between 'turkey' and 'turkey stock': 0.5
# Jaccard_similarity between 'turkey' and 'turkey wings': 0.5
# Jaccard_similarity between 'turkey breast' and 'turkey breast fillets': 0.6666666666666666
# Jaccard_similarity between 'turkey breast' and 'turkey breast tenderloin steak': 0.5
# Jaccard_similarity between 'turkey italian sausage' and 'turkey sausage': 0.6666666666666666
# Jaccard_similarity between 'turkey stock' and 'white stock': 0.5
# Jaccard_similarity between 'unsweetened chocolate' and 'white chocolate': 0.5
# Jaccard_similarity between 'vanilla bean' and 'vanilla extract': 0.5
# Jaccard_similarity between 'vanilla custard' and 'vanilla extract': 0.5
# Jaccard_similarity between 'vanilla extract' and 'vanilla frosting': 0.5
# Jaccard_similarity between 'vanilla extract' and 'vanilla sugar': 0.5
# Jaccard_similarity between 'vanilla extract' and 'vanilla wafers': 0.5
# Jaccard_similarity between 'vanilla extract' and 'vanilla yogurt': 0.5
# Jaccard_similarity between 'vanilla yogurt' and 'yogurt': 0.5
# Jaccard_similarity between 'veal' and 'veal breast': 0.5
# Jaccard_similarity between 'veal' and 'veal cutlets': 0.5
# Jaccard_similarity between 'veal' and 'veal knuckle': 0.5
# Jaccard_similarity between 'veal' and 'veal shoulder': 0.5
# Jaccard_similarity between 'vegetable stock' and 'vegetable stock cubes': 0.6666666666666666
# Jaccard_similarity between 'vegetable stock' and 'white stock': 0.5
# Jaccard_similarity between 'venison' and 'venison chops': 0.5
# Jaccard_similarity between 'vinegar' and 'white vinegar': 1.0
# Jaccard_similarity between 'vinegar' and 'white wine vinegar': 0.5
# Jaccard_similarity between 'water' and 'water chestnuts': 0.5
# Jaccard_similarity between 'watermelon' and 'watermelon seeds': 0.5
# Jaccard_similarity between 'wax beans' and 'white beans': 0.5
# Jaccard_similarity between 'white beans' and 'white nothern beans': 0.5
# Jaccard_similarity between 'white chocolate' and 'white chocolate chips': 0.5
# Jaccard_similarity between 'white hominy' and 'yellow hominy': 1.0
# Jaccard_similarity between 'white onion' and 'yellow onion': 1.0
# Jaccard_similarity between 'white vinegar' and 'white wine vinegar': 0.5
# Jaccard_similarity between 'white wine' and 'white wine vinegar': 0.5
# Jaccard_similarity between 'white wine' and 'wine': 1.0
# Jaccard_similarity between 'white wine vinegar' and 'wine': 0.5
# Jaccard_similarity between 'wholewheat flour' and 'wholewheat pastry flour': 0.6666666666666666
# Jaccard_similarity between 'yeast cakes' and 'yeast extract': 0.5
# Jaccard_similarity between 'yogurt' and 'yogurt lowfat': 0.5
# Jaccard_similarity between 'yogurt' and 'yogurt nonfat': 0.5
# Jaccard_similarity between 'yogurt' and 'yogurt plain': 0.5

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

strs = [remove_colors(string, color_words) for string in strings]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(strs).toarray()

smst = []
for i in range(len(strings)):
    for j in range(i + 1, len(strings)):
        similarity = cosine_similarity([X[i]], [X[j]])[0][0]
        # a = any(word in str1 for word in exclude_words)
        # b = any(word in str2 for word in exclude_words)
        # xnor = (a and b) or (not a and not b)
        # c = ' ' in str1
        # d = ' ' in str2
        # ord = c or d
        if(similarity > 0.8 ): #and xnor and ord
            smst.append([strings[i],strings[j]])
            print(f"Cosine similarity between '{strings[i]}' and '{strings[j]}': {similarity}")
# Out:
# Cosine similarity between 'Almond Red Sauce' and 'almond extract': 0.8317961530960255
# Cosine similarity between 'Apple Cider Sauce' and 'apple cider': 0.9122003986967189
# Cosine similarity between 'Chinese rice vinegar' and 'chinese black vinegar': 0.8463294027621928
# Cosine similarity between 'Gram flour' and 'gram': 0.8205526300859373
# Cosine similarity between 'Italian Dressing' and 'Italian Dressing Mix': 0.868986090359897
# Cosine similarity between 'Italian Dressing' and 'salad dressing italian': 0.8137851044433708
# Cosine similarity between 'Italian Dressing Mix' and 'salad dressing mix italian': 0.849678952871338
# Cosine similarity between 'Lemon Cream Cheese Frosting' and 'cream cheese frosting': 0.8504380488549079
# Cosine similarity between 'Roasted Baby Vidalia Onions' and 'baby vidalia onions': 0.8478975191660203
# Cosine similarity between 'Sage Buttermilk Biscuits' and 'buttermilk biscuits': 0.8057891831929658
# Cosine similarity between 'apple cider' and 'apple cider vinegar': 0.8615717459456695
# Cosine similarity between 'baby lima beans' and 'lima beans': 0.8136669210832396
# Cosine similarity between 'bacon bits' and 'imitation bacon bits': 0.8007913737211175
# Cosine similarity between 'bean curd' and 'bean curd cake': 0.8402138372894055
# Cosine similarity between 'beans' and 'black beans': 1.0
# Cosine similarity between 'beans' and 'brown beans': 1.0
# Cosine similarity between 'beans' and 'green beans': 1.0
# Cosine similarity between 'beans' and 'red beans': 1.0
# Cosine similarity between 'beans' and 'white beans': 1.0
# Cosine similarity between 'beans ranch style' and 'ranch style beans': 1.0
# Cosine similarity between 'beef bouillon cubes' and 'bouillon cubes': 0.8856165020781199
# Cosine similarity between 'beef chuck' and 'beef chuck roast': 0.8097271726205211
# Cosine similarity between 'beef chuck' and 'beef chuck steak': 0.8236125089353082
# Cosine similarity between 'beef gravy' and 'gravy': 0.8164180410597947
# Cosine similarity between 'beef roast' and 'beef roast pot roast': 0.8238200558945459
# Cosine similarity between 'beef roast' and 'roast beef': 1.0000000000000002
# Cosine similarity between 'beef roast pot roast' and 'roast beef': 0.8238200558945459
# Cosine similarity between 'beef soup bones' and 'soup bones': 0.8695906265147215
# Cosine similarity between 'beef suet' and 'suet': 0.8348699431357415
# Cosine similarity between 'black bean sauce' and 'brown bean sauce': 1.0000000000000002
# Cosine similarity between 'black bean sauce' and 'yellow bean sauce': 1.0000000000000002
# Cosine similarity between 'black beans' and 'brown beans': 1.0
# Cosine similarity between 'black beans' and 'green beans': 1.0
# Cosine similarity between 'black beans' and 'red beans': 1.0
# Cosine similarity between 'black beans' and 'white beans': 1.0
# Cosine similarity between 'black currants' and 'currants': 1.0
# Cosine similarity between 'black currants' and 'red currants': 1.0
# Cosine similarity between 'black gram beans' and 'gram': 0.8108622731275777
# Cosine similarity between 'black licorice' and 'licorice': 1.0
# Cosine similarity between 'black mustard' and 'brown mustard': 1.0
# Cosine similarity between 'black mustard' and 'english mustard': 1.0
# Cosine similarity between 'black olives' and 'green olives': 1.0
# Cosine similarity between 'black olives' and 'olives': 1.0
# Cosine similarity between 'black pepper' and 'white pepper': 1.0
# Cosine similarity between 'black peppercorns' and 'green peppercorns': 1.0
# Cosine similarity between 'black peppercorns' and 'peppercorns': 1.0
# Cosine similarity between 'black peppercorns' and 'white peppercorns': 1.0
# Cosine similarity between 'blue cheese' and 'cheese': 1.0
# Cosine similarity between 'boneless leg of lamb' and 'leg of lamb': 0.8476648799540851
# Cosine similarity between 'bouillon cubes' and 'chicken bouillon cubes': 0.8698105455372694
# Cosine similarity between 'bread' and 'white bread': 1.0
# Cosine similarity between 'bread crumbs whole wheat' and 'whole wheat bread': 0.856320996239882
# Cosine similarity between 'brown bean sauce' and 'yellow bean sauce': 1.0000000000000002
# Cosine similarity between 'brown beans' and 'green beans': 1.0
# Cosine similarity between 'brown beans' and 'red beans': 1.0
# Cosine similarity between 'brown beans' and 'white beans': 1.0
# Cosine similarity between 'brown lentils' and 'lentils': 1.0
# Cosine similarity between 'brown lentils' and 'lentils green': 1.0
# Cosine similarity between 'brown lentils' and 'lentils yellow': 1.0
# Cosine similarity between 'brown mustard' and 'english mustard': 1.0
# Cosine similarity between 'brown rice' and 'rice': 1.0
# Cosine similarity between 'brown rice flour' and 'rice flour': 1.0
# Cosine similarity between 'brown rice syrup' and 'rice syrup': 1.0
# Cosine similarity between 'brown rice vinegar' and 'rice vinegar': 1.0
# Cosine similarity between 'brown sugar' and 'sugar': 1.0
# Cosine similarity between 'burgundy wine' and 'red burgundy wine': 1.0
# Cosine similarity between 'cabbage' and 'red cabbage': 1.0
# Cosine similarity between 'cabbage leaves' and 'red cabbage leaves': 1.0
# Cosine similarity between 'cake mix' and 'cake mix chocolate': 0.8400924086426287
# Cosine similarity between 'cake mix' and 'cake mix white': 1.0
# Cosine similarity between 'cake mix' and 'cake mix yellow': 1.0
# Cosine similarity between 'cake mix chocolate' and 'cake mix white': 0.8400924086426287
# Cosine similarity between 'cake mix chocolate' and 'cake mix yellow': 0.8400924086426287
# Cosine similarity between 'cake mix white' and 'cake mix yellow': 1.0
# Cosine similarity between 'candied orange peel' and 'candied peel': 0.8429059023161349
# Cosine similarity between 'candied peel' and 'mixed candied peel': 0.8217617055314606
# Cosine similarity between 'candies' and 'chocolate candies': 0.8454266221764253
# Cosine similarity between 'cayenne pepper' and 'cayenne pepper sauce': 0.9060682514769395
# Cosine similarity between 'champagne' and 'champagne vinegar': 0.8056243310015933
# Cosine similarity between 'cheese tortellini' and 'tortellini': 0.8644192180206061
# Cosine similarity between 'chili pepper flakes' and 'red pepper flakes': 0.8270701059298009
# Cosine similarity between 'chili sauce' and 'red chili sauce': 1.0
# Cosine similarity between 'chili seasoning mix' and 'seasoning mix': 0.8113468579453662
# Cosine similarity between 'chocolate' and 'chocolate extract': 1.0
# Cosine similarity between 'chocolate' and 'white chocolate': 1.0
# Cosine similarity between 'chocolate bars' and 'milk chocolate bars': 0.8384236331837669
# Cosine similarity between 'chocolate chips' and 'white chocolate chips': 1.0
# Cosine similarity between 'chocolate chips semisweet' and 'semisweet chocolate': 0.8406533878121002
# Cosine similarity between 'chocolate cookie crumbs' and 'cookie crumbs': 0.8948937349885401
# Cosine similarity between 'chocolate cookies' and 'cookies': 0.8146696634699528
# Cosine similarity between 'chocolate extract' and 'white chocolate': 1.0
# Cosine similarity between 'chocolate ice cream' and 'ice cream': 0.8613392733603813
# Cosine similarity between 'chocolate milk mix' and 'milk chocolate': 0.8473272151963154
# Cosine similarity between 'chocolate mints' and 'mints': 0.8454266221764253
# Cosine similarity between 'coconut' and 'coconut extract': 1.0
# Cosine similarity between 'coconut cream' and 'cream of coconut': 0.8119496585084647
# Cosine similarity between 'coleslaw' and 'coleslaw mix': 0.8523134083314831
# Cosine similarity between 'corn' and 'yellow corn': 1.0
# Cosine similarity between 'corn grits' and 'grits': 0.8078949354709665
# Cosine similarity between 'corn muffin mix' and 'muffin mix': 0.8425084390484711
# Cosine similarity between 'cracker crumbs' and 'graham cracker crumbs': 0.8007983041077091
# Cosine similarity between 'cream sherry' and 'sherry': 0.8146545610620418
# Cosine similarity between 'cumin' and 'cumin seeds': 0.8100696129536972
# Cosine similarity between 'currants' and 'red currants': 1.0
# Cosine similarity between 'ditalini' and 'pasta ditalini': 0.8179494341602632
# Cosine similarity between 'enchilada sauce' and 'green enchilada sauce': 1.0
# Cosine similarity between 'fenugreek' and 'fenugreek leaves': 0.8108622731275777
# Cosine similarity between 'fish' and 'fish sauce': 0.8206914284994764
# Cosine similarity between 'garlic' and 'garlic sauce': 0.8082868779639132
# Cosine similarity between 'grape juice' and 'white grape juice': 1.0
# Cosine similarity between 'grapefruit' and 'grapefruit juice': 0.8175146402094439
# Cosine similarity between 'gravy' and 'gravy mix brown': 0.8352511441884585
# Cosine similarity between 'green beans' and 'red beans': 1.0
# Cosine similarity between 'green beans' and 'white beans': 1.0
# Cosine similarity between 'green bell peppers' and 'sweet bell peppers': 0.8396326685507203
# Cosine similarity between 'green bell peppers' and 'sweet red bell peppers': 0.8396326685507203
# Cosine similarity between 'green bell peppers' and 'sweet yellow bell peppers': 0.8396326685507203
# Cosine similarity between 'green chili peppers' and 'hot chili peppers': 0.8193508194676737
# Cosine similarity between 'green chili peppers' and 'red chili peppers': 1.0000000000000002
# Cosine similarity between 'green curry paste' and 'red curry paste': 1.0000000000000002
# Cosine similarity between 'green grapes' and 'red grapes': 1.0
# Cosine similarity between 'green olives' and 'olives': 1.0
# Cosine similarity between 'green onions' and 'onions': 1.0
# Cosine similarity between 'green peppercorns' and 'peppercorns': 1.0
# Cosine similarity between 'green peppercorns' and 'white peppercorns': 1.0
# Cosine similarity between 'green salsa' and 'salsa': 1.0
# Cosine similarity between 'green tea' and 'tea': 1.0
# Cosine similarity between 'green tomatoes' and 'tomatoes': 1.0
# Cosine similarity between 'green tomatoes' and 'yellow tomatoes': 1.0
# Cosine similarity between 'ground beef' and 'ground chuck ground beef': 0.8337633886874778
# Cosine similarity between 'ground beef lean' and 'lean ground beef patty': 0.8131736195190983
# Cosine similarity between 'harissa' and 'harissa sauce': 0.8722775787116609
# Cosine similarity between 'herbal tea bags' and 'tea bags': 0.8117804590763296
# Cosine similarity between 'honeydew melon' and 'honeydew melon balls': 0.8268926330127374
# Cosine similarity between 'horseradish' and 'horseradish sauce': 0.8639469608227482
# Cosine similarity between 'hot chili peppers' and 'red chili peppers': 0.8193508194676737
# Cosine similarity between 'hot dog buns' and 'hot dogs and hot dog buns': 0.8030553641783775
# Cosine similarity between 'instant pudding mix' and 'instant pudding mix chocolate': 0.908630182738397
# Cosine similarity between 'instant pudding mix' and 'instant pudding mix pistachio': 0.8086471748595722
# Cosine similarity between 'instant pudding mix' and 'instant pudding mix vanilla': 0.8599304889145384
# Cosine similarity between 'italian sausage' and 'turkey italian sausage': 0.8152111338025969
# Cosine similarity between 'juice' and 'v juice': 1.0
# Cosine similarity between 'kaffir lime' and 'kaffir lime leaves': 0.8858416260903927
# Cosine similarity between 'lamb shoulder' and 'lamb shoulder chops': 0.811356570497342
# Cosine similarity between 'lasagna noodles' and 'spinach lasagna noodles': 0.8233727983967163
# Cosine similarity between 'lemon' and 'lemon extract': 1.0
# Cosine similarity between 'lentils' and 'lentils green': 1.0
# Cosine similarity between 'lentils' and 'lentils yellow': 1.0
# Cosine similarity between 'lentils green' and 'lentils yellow': 1.0
# Cosine similarity between 'lettuce' and 'red lettuce': 1.0
# Cosine similarity between 'liquid sugar substitute' and 'sugar substitute': 0.8296453535058312
# Cosine similarity between 'meat' and 'meat extract': 1.0
# Cosine similarity between 'meat' and 'meat sauce': 0.814213634293493
# Cosine similarity between 'meat extract' and 'meat sauce': 0.814213634293493
# Cosine similarity between 'millet' and 'millet flour': 0.8307882988002411
# Cosine similarity between 'miso paste' and 'white miso paste': 1.0
# Cosine similarity between 'mozzarella cheese' and 'soy cheese mozzarella': 0.8065775345562991
# Cosine similarity between 'mustard seeds' and 'mustard seeds black': 1.0
# Cosine similarity between 'orange roughy' and 'orange roughy fillets': 0.8506357392832766
# Cosine similarity between 'palm' and 'palm oil': 0.8011811014156692
# Cosine similarity between 'pasta fettuccine' and 'pasta spinach fettuccine': 0.8148474707988496
# Cosine similarity between 'peanut butter' and 'peanut butter chips': 0.8482764798826099
# Cosine similarity between 'peppercorns' and 'white peppercorns': 1.0
# Cosine similarity between 'pinto' and 'pinto beans': 0.8108622731275777
# Cosine similarity between 'pita bread whole wheat' and 'whole wheat bread': 0.8015774228527666
# Cosine similarity between 'pizza crust dough' and 'pizza dough': 0.8041816313877361
# Cosine similarity between 'pomegranate' and 'pomegranate juice': 0.8175146402094439
# Cosine similarity between 'pork loin' and 'pork loin roast': 0.8173129474812808
# Cosine similarity between 'pork sausage meat' and 'sausage meat': 0.836782750592205
# Cosine similarity between 'potato starch' and 'potato starch flour': 0.8940393077730941
# Cosine similarity between 'puff pastry' and 'puff pastry shells': 0.8432289711694017
# Cosine similarity between 'ramen noodles' and 'soup ramen noodles': 0.8674299646522767
# Cosine similarity between 'red beans' and 'white beans': 1.0
# Cosine similarity between 'red onion' and 'white onion': 1.0
# Cosine similarity between 'red onion' and 'yellow onion': 1.0
# Cosine similarity between 'red vinegar' and 'vinegar': 1.0
# Cosine similarity between 'red vinegar' and 'white vinegar': 1.0
# Cosine similarity between 'red wine' and 'white wine': 1.0
# Cosine similarity between 'red wine' and 'wine': 1.0
# Cosine similarity between 'red wine vinegar' and 'white wine vinegar': 1.0000000000000002
# Cosine similarity between 'rum' and 'rum extract': 1.0
# Cosine similarity between 'rye' and 'rye flour': 0.804654771736252
# Cosine similarity between 'sage' and 'sage leaves': 0.8108622731275777
# Cosine similarity between 'salad dressing' and 'salad dressing italian': 0.817848948090689
# Cosine similarity between 'salad dressing creamy' and 'salad dressing creamy ranch': 0.8451931661101397
# Cosine similarity between 'salad dressing italian' and 'salad dressing italian lowfat': 0.8247640676834869
# Cosine similarity between 'salad dressing italian' and 'salad dressing mix italian': 0.9073147041955175
# Cosine similarity between 'salad dressing italian lowfat' and 'salad dressing lowfat': 0.8802035135550292
# Cosine similarity between 'salt and black pepper' and 'salt and white pepper': 1.0000000000000002
# Cosine similarity between 'sauterne' and 'sauterne wine': 0.8007593622302951
# Cosine similarity between 'smoked turkey breast' and 'turkey breast': 0.8043739660267728
# Cosine similarity between 'soup mix vegetable dry' and 'soup vegetable mix': 0.8302734879565049
# Cosine similarity between 'soup mix vegetable dry' and 'vegetable soup mix dry': 1.0000000000000002
# Cosine similarity between 'soup vegetable mix' and 'vegetable soup mix dry': 0.8302734879565049
# Cosine similarity between 'sourdough' and 'sourdough bread': 0.8090609598318026
# Cosine similarity between 'spaghetti' and 'spaghetti sauce': 0.8569558416558671
# Cosine similarity between 'split peas' and 'yellow split peas': 1.0
# Cosine similarity between 'stock' and 'white stock': 1.0
# Cosine similarity between 'stuffing' and 'stuffing mix': 0.828508131281915
# Cosine similarity between 'sweet bell peppers' and 'sweet red bell peppers': 1.0
# Cosine similarity between 'sweet bell peppers' and 'sweet yellow bell peppers': 1.0
# Cosine similarity between 'sweet red bell peppers' and 'sweet yellow bell peppers': 1.0
# Cosine similarity between 'tamarind' and 'tamarind juice': 0.8278707166721184
# Cosine similarity between 'tapioca' and 'tapioca flour': 0.8205526300859373
# Cosine similarity between 'tomatoes' and 'yellow tomatoes': 1.0
# Cosine similarity between 'turkey breast' and 'turkey breast fillets': 0.8269495547492243
# Cosine similarity between 'turkey italian sausage' and 'turkey sausage': 0.8152111338025969
# Cosine similarity between 'vinegar' and 'white vinegar': 1.0
# Cosine similarity between 'watermelon' and 'watermelon seeds': 0.8100696129536973
# Cosine similarity between 'white hominy' and 'yellow hominy': 1.0
# Cosine similarity between 'white onion' and 'yellow onion': 1.0
# Cosine similarity between 'white wine' and 'wine': 1.0
# Cosine similarity between 'wholewheat flour' and 'wholewheat pastry flour': 0.8112264275610777

# %%
def remove_colors(string, color_list):
    pattern = re.compile(r'\b(?:' + '|'.join(re.escape(color) for color in color_list) + r')\b', flags=re.IGNORECASE)
    string_without_colors = re.sub(pattern, '', string)
    return string_without_colors.strip()
    
from jellyfish import jaro_winkler_similarity

strings = vectorizer.get_feature_names_out()

color_words = ['red', 'blue', 'green', 'yellow','white','black','brown','english','extract']
exclude_words = ["ground", "sauce", "milk", "oil","seeds","powder","flour","crumbs","broth","salt","beef","zest","vinegar","paste","shortening","noodles","stock"]

smst = []

for i in range(len(strings)):
    for j in range(i + 1, len(strings)):
        str1 = remove_colors(strings[i], color_words)
        str2 = remove_colors(strings[j], color_words)
        similarity = jaro_winkler_similarity(str1, str2)
        a = any(word in str1 for word in exclude_words)
        b = any(word in str2 for word in exclude_words)
        xnor = (a and b) or (not a and not b)
        c = ' ' in str1
        d = ' ' in str2
        ord = c or d
        if(similarity > 0.89 and xnor and ord):
            smst.append([strings[i],strings[j]])
            print(f"Jaro-Winkler similarity between '{strings[i]}' and '{strings[j]}': {similarity}")
# Out:
# Jaro-Winkler similarity between 'Italian Dressing' and 'Italian Dressing Mix': 0.96
# Jaro-Winkler similarity between 'allspice' and 'allspice berries': 0.9
# Jaro-Winkler similarity between 'almond butter' and 'almond extract': 0.8923076923076924
# Jaro-Winkler similarity between 'almond extract' and 'almond meal': 0.9090909090909091
# Jaro-Winkler similarity between 'almond milk' and 'almond oil': 0.9436363636363637
# Jaro-Winkler similarity between 'apple cider' and 'apple juice': 0.905050505050505
# Jaro-Winkler similarity between 'apple cider' and 'apple wine': 0.9054545454545454
# Jaro-Winkler similarity between 'apple jelly' and 'apple juice': 0.890909090909091
# Jaro-Winkler similarity between 'apple juice' and 'apple juice concentrate': 0.8956521739130435
# Jaro-Winkler similarity between 'apple juice' and 'apple wine': 0.9054545454545454
# Jaro-Winkler similarity between 'apricot brandy' and 'apricot nectar': 0.8961038961038961
# Jaro-Winkler similarity between 'apricots' and 'apricots dried': 0.9142857142857143
# Jaro-Winkler similarity between 'artichoke hearts' and 'artichokes': 0.925
# Jaro-Winkler similarity between 'baby shrimp' and 'baby spinach': 0.8914141414141414
# Jaro-Winkler similarity between 'bacon' and 'bacon bits': 0.9
# Jaro-Winkler similarity between 'banana chips' and 'bananas': 0.9166666666666667
# Jaro-Winkler similarity between 'basil' and 'basil pesto': 0.890909090909091
# Jaro-Winkler similarity between 'bean curd' and 'bean curd cake': 0.9285714285714286
# Jaro-Winkler similarity between 'bean curd' and 'bean curd sheets': 0.9125
# Jaro-Winkler similarity between 'bean curd cake' and 'bean curd sheets': 0.8946428571428571
# Jaro-Winkler similarity between 'bean dip' and 'beans dried': 0.9022727272727272
# Jaro-Winkler similarity between 'bean dip' and 'black beans dried': 0.9022727272727272
# Jaro-Winkler similarity between 'bean paste' and 'black bean sauce': 0.895
# Jaro-Winkler similarity between 'bean paste' and 'brown bean sauce': 0.895
# Jaro-Winkler similarity between 'bean paste' and 'yellow bean sauce': 0.895
# Jaro-Winkler similarity between 'beans' and 'beans dried': 0.890909090909091
# Jaro-Winkler similarity between 'beans' and 'black beans dried': 0.890909090909091
# Jaro-Winkler similarity between 'beans dried' and 'black beans': 0.890909090909091
# Jaro-Winkler similarity between 'beans dried' and 'black beans dried': 1.0
# Jaro-Winkler similarity between 'beans dried' and 'brown beans': 0.890909090909091
# Jaro-Winkler similarity between 'beans dried' and 'green beans': 0.890909090909091
# Jaro-Winkler similarity between 'beans dried' and 'peas dried': 0.9060606060606061
# Jaro-Winkler similarity between 'beans dried' and 'red beans': 0.890909090909091
# Jaro-Winkler similarity between 'beans dried' and 'white beans': 0.890909090909091
# Jaro-Winkler similarity between 'beans with pork canned' and 'green beans canned': 0.9090909090909091
# Jaro-Winkler similarity between 'beef base' and 'beef blade steak': 0.8902777777777778
# Jaro-Winkler similarity between 'beef base' and 'beef brisket': 0.9111111111111111
# Jaro-Winkler similarity between 'beef base' and 'beef roast': 0.8955555555555555
# Jaro-Winkler similarity between 'beef base' and 'beef steak': 0.9127777777777778
# Jaro-Winkler similarity between 'beef base' and 'beef suet': 0.9111111111111111
# Jaro-Winkler similarity between 'beef blade steak' and 'beef tbone steak': 0.8942307692307693
# Jaro-Winkler similarity between 'beef bouillon cubes' and 'beef bouillon granules': 0.9334928229665072
# Jaro-Winkler similarity between 'beef brisket' and 'beef roast': 0.8933333333333334
# Jaro-Winkler similarity between 'beef brisket' and 'beef steak': 0.9077777777777777
# Jaro-Winkler similarity between 'beef brisket' and 'beef suet': 0.9111111111111111
# Jaro-Winkler similarity between 'beef chuck' and 'beef chuck roast': 0.925
# Jaro-Winkler similarity between 'beef chuck' and 'beef chuck steak': 0.925
# Jaro-Winkler similarity between 'beef chuck roast' and 'beef chuck steak': 0.9357142857142857
# Jaro-Winkler similarity between 'beef chuck roast' and 'beef roast': 0.925
# Jaro-Winkler similarity between 'beef roast' and 'beef roast pot roast': 0.9
# Jaro-Winkler similarity between 'beef roast' and 'beef roast ribeye': 0.9176470588235295
# Jaro-Winkler similarity between 'beef roast' and 'beef roast rump': 0.9333333333333333
# Jaro-Winkler similarity between 'beef roast' and 'beef round steak': 0.905
# Jaro-Winkler similarity between 'beef roast' and 'beef steak': 0.895
# Jaro-Winkler similarity between 'beef roast' and 'beef stock': 0.895
# Jaro-Winkler similarity between 'beef roast' and 'beef suet': 0.8955555555555555
# Jaro-Winkler similarity between 'beef roast ribeye' and 'beef roast rump': 0.9011764705882354
# Jaro-Winkler similarity between 'beef roast ribeye' and 'beef short ribs': 0.9108898944193061
# Jaro-Winkler similarity between 'beef round steak' and 'beef sirloin steak': 0.901984126984127
# Jaro-Winkler similarity between 'beef round steak' and 'beef steak': 0.925
# Jaro-Winkler similarity between 'beef sirloin steak' and 'beef sirloin tip': 0.9305555555555555
# Jaro-Winkler similarity between 'beef sirloin steak' and 'beef skirt steak': 0.9162698412698412
# Jaro-Winkler similarity between 'beef sirloin steak' and 'beef steak': 0.9111111111111111
# Jaro-Winkler similarity between 'beef steak' and 'beef stock': 0.92
# Jaro-Winkler similarity between 'beef steak' and 'beef suet': 0.9127777777777778
# Jaro-Winkler similarity between 'beef steak' and 'beef tbone steak': 0.905
# Jaro-Winkler similarity between 'beef stock' and 'beef suet': 0.8955555555555555
# Jaro-Winkler similarity between 'black bean sauce' and 'brown bean sauce': 1.0
# Jaro-Winkler similarity between 'black bean sauce' and 'yellow bean sauce': 1.0
# Jaro-Winkler similarity between 'black beans' and 'black beans dried': 0.890909090909091
# Jaro-Winkler similarity between 'black beans dried' and 'brown beans': 0.890909090909091
# Jaro-Winkler similarity between 'black beans dried' and 'green beans': 0.890909090909091
# Jaro-Winkler similarity between 'black beans dried' and 'peas dried': 0.9060606060606061
# Jaro-Winkler similarity between 'black beans dried' and 'red beans': 0.890909090909091
# Jaro-Winkler similarity between 'black beans dried' and 'white beans': 0.890909090909091
# Jaro-Winkler similarity between 'black mustard' and 'mustard greens': 0.9
# Jaro-Winkler similarity between 'black pepper' and 'red pepper flakes': 0.8923076923076924
# Jaro-Winkler similarity between 'blue cheese' and 'cheese cloth': 0.9
# Jaro-Winkler similarity between 'bouillon' and 'bouillon cubes': 0.9142857142857143
# Jaro-Winkler similarity between 'bourbon' and 'bourbon whiskey': 0.8933333333333334
# Jaro-Winkler similarity between 'bread' and 'bread dough': 0.890909090909091
# Jaro-Winkler similarity between 'bread crumbs' and 'bread crumbs whole wheat': 0.9
# Jaro-Winkler similarity between 'bread dough' and 'white bread': 0.890909090909091
# Jaro-Winkler similarity between 'broccoli florets' and 'broccoli frozen': 0.9204487179487179
# Jaro-Winkler similarity between 'broccoli florets' and 'broccoli stems': 0.9047619047619048
# Jaro-Winkler similarity between 'broccoli slaw' and 'broccoli stems': 0.8967032967032967
# Jaro-Winkler similarity between 'brown bean sauce' and 'yellow bean sauce': 1.0
# Jaro-Winkler similarity between 'brown mustard' and 'mustard greens': 0.9
# Jaro-Winkler similarity between 'brown rice flour' and 'rice flour': 1.0
# Jaro-Winkler similarity between 'brown rice flour' and 'rye flour': 0.9066666666666667
# Jaro-Winkler similarity between 'brown rice syrup' and 'rice syrup': 1.0
# Jaro-Winkler similarity between 'brown rice vinegar' and 'rice vinegar': 1.0
# Jaro-Winkler similarity between 'brown sugar' and 'brown sugar dark': 0.9
# Jaro-Winkler similarity between 'brown sugar' and 'brown sugar light': 0.890909090909091
# Jaro-Winkler similarity between 'brown sugar' and 'sugar cane': 0.9
# Jaro-Winkler similarity between 'brown sugar dark' and 'sugar': 0.9
# Jaro-Winkler similarity between 'brown sugar light' and 'sugar': 0.890909090909091
# Jaro-Winkler similarity between 'burgundy wine' and 'red burgundy wine': 1.0
# Jaro-Winkler similarity between 'butter' and 'butter buds': 0.9090909090909091
# Jaro-Winkler similarity between 'buttercup squash' and 'butternut squash': 0.95
# Jaro-Winkler similarity between 'buttermilk' and 'buttermilk baking mix': 0.8952380952380953
# Jaro-Winkler similarity between 'buttermilk' and 'buttermilk biscuits': 0.9052631578947368
# Jaro-Winkler similarity between 'buttermilk' and 'buttermilk mayonnaise': 0.8952380952380953
# Jaro-Winkler similarity between 'buttermilk' and 'buttermilk pancake mix': 0.890909090909091
# Jaro-Winkler similarity between 'buttermilk' and 'buttermilk powdered': 0.9052631578947368
# Jaro-Winkler similarity between 'buttermilk baking mix' and 'buttermilk pancake mix': 0.9128427128427129
# Jaro-Winkler similarity between 'cabbage' and 'cabbage leaves': 0.9
# Jaro-Winkler similarity between 'cabbage' and 'red cabbage leaves': 0.9
# Jaro-Winkler similarity between 'cabbage leaves' and 'red cabbage': 0.9
# Jaro-Winkler similarity between 'cabbage leaves' and 'red cabbage leaves': 1.0
# Jaro-Winkler similarity between 'cake' and 'cake mix': 0.9
# Jaro-Winkler similarity between 'cake' and 'cake mix white': 0.9
# Jaro-Winkler similarity between 'cake' and 'cake mix yellow': 0.9
# Jaro-Winkler similarity between 'cake crumbs' and 'cookie crumbs': 0.9034965034965035
# Jaro-Winkler similarity between 'cake meal' and 'cracker meal': 0.9249999999999999
# Jaro-Winkler similarity between 'cake mix' and 'cake mix lemon': 0.9142857142857143
# Jaro-Winkler similarity between 'cake mix' and 'cake mix orange': 0.9066666666666666
# Jaro-Winkler similarity between 'cake mix' and 'cake mix white': 1.0
# Jaro-Winkler similarity between 'cake mix' and 'cake mix yellow': 1.0
# Jaro-Winkler similarity between 'cake mix chocolate' and 'cake mix german chocolate': 0.8995555555555556
# Jaro-Winkler similarity between 'cake mix chocolate' and 'cake mix orange': 0.8933333333333334
# Jaro-Winkler similarity between 'cake mix lemon' and 'cake mix orange': 0.9147619047619048
# Jaro-Winkler similarity between 'cake mix lemon' and 'cake mix white': 0.9142857142857143
# Jaro-Winkler similarity between 'cake mix lemon' and 'cake mix yellow': 0.9142857142857143
# Jaro-Winkler similarity between 'cake mix orange' and 'cake mix white': 0.9066666666666666
# Jaro-Winkler similarity between 'cake mix orange' and 'cake mix yellow': 0.9066666666666666
# Jaro-Winkler similarity between 'cake mix white' and 'cake mix yellow': 1.0
# Jaro-Winkler similarity between 'candied cherries' and 'candied cherry halves': 0.9303571428571429
# Jaro-Winkler similarity between 'candied cherries' and 'candied peel': 0.8916666666666667
# Jaro-Winkler similarity between 'candied citron' and 'candied fruit': 0.9081918081918082
# Jaro-Winkler similarity between 'candied orange peel' and 'candied peel': 0.9096491228070176
# Jaro-Winkler similarity between 'candied peel' and 'candied pineapple': 0.9245098039215687
# Jaro-Winkler similarity between 'candy' and 'candy canes': 0.890909090909091
# Jaro-Winkler similarity between 'candy' and 'candy corn': 0.9
# Jaro-Winkler similarity between 'candy canes' and 'candy corn': 0.9054545454545454
# Jaro-Winkler similarity between 'canned ham' and 'canned salmon': 0.9184615384615384
# Jaro-Winkler similarity between 'caramel sauce' and 'cream sauce': 0.8993006993006994
# Jaro-Winkler similarity between 'carrot juice' and 'carrot puree': 0.9
# Jaro-Winkler similarity between 'cashew butter' and 'cashew nuts': 0.9020979020979021
# Jaro-Winkler similarity between 'catfish' and 'catfish fillets': 0.8933333333333334
# Jaro-Winkler similarity between 'catfish fillets' and 'fish fillets': 0.9333333333333332
# Jaro-Winkler similarity between 'celery' and 'celery flakes': 0.8923076923076924
# Jaro-Winkler similarity between 'celery' and 'celery heart': 0.9
# Jaro-Winkler similarity between 'celery' and 'celery leaves': 0.8923076923076924
# Jaro-Winkler similarity between 'celery' and 'celery stalks': 0.8923076923076924
# Jaro-Winkler similarity between 'celery flakes' and 'celery leaves': 0.9202797202797203
# Jaro-Winkler similarity between 'celery flakes' and 'celery stalks': 0.9202797202797203
# Jaro-Winkler similarity between 'chana dall' and 'channa dal': 0.96
# Jaro-Winkler similarity between 'cheddar cheese' and 'cheddar cheese medium': 0.9333333333333333
# Jaro-Winkler similarity between 'cheddar cheese' and 'cheddar cheese mild': 0.9473684210526316
# Jaro-Winkler similarity between 'cheddar cheese' and 'cheddar cheese reducedfat': 0.912
# Jaro-Winkler similarity between 'cheddar cheese' and 'cheddar cheese very old sharp': 0.896551724137931
# Jaro-Winkler similarity between 'cheddar cheese medium' and 'cheddar cheese mild': 0.9497911445279866
# Jaro-Winkler similarity between 'cheddar cheese medium' and 'cheddar cheese reducedfat': 0.9154285714285714
# Jaro-Winkler similarity between 'cheddar cheese mild' and 'cheddar cheese reducedfat': 0.896421052631579
# Jaro-Winkler similarity between 'cheddar cheese mild' and 'cheddar cheese very old sharp': 0.8961887477313975
# Jaro-Winkler similarity between 'cheese' and 'cheese cloth': 0.9
# Jaro-Winkler similarity between 'cherries' and 'cherries dried': 0.9142857142857143
# Jaro-Winkler similarity between 'cherries' and 'cherry juice': 0.8916666666666667
# Jaro-Winkler similarity between 'chestnut honey' and 'chestnuts': 0.8920634920634921
# Jaro-Winkler similarity between 'chicken' and 'chicken breasts': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken' and 'chicken canned': 0.9
# Jaro-Winkler similarity between 'chicken' and 'chicken cutlets': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken' and 'chicken gravy': 0.9076923076923077
# Jaro-Winkler similarity between 'chicken' and 'chicken legs': 0.9166666666666667
# Jaro-Winkler similarity between 'chicken' and 'chicken livers': 0.9
# Jaro-Winkler similarity between 'chicken' and 'chicken pieces': 0.9
# Jaro-Winkler similarity between 'chicken' and 'chicken sausage': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken' and 'chicken tenders': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken' and 'chicken wings': 0.9076923076923077
# Jaro-Winkler similarity between 'chicken breast halves boneless skinless' and 'chicken breast halves boneless skinon': 0.9686763686763686
# Jaro-Winkler similarity between 'chicken breasts' and 'chicken drumsticks': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken breasts' and 'chicken legs': 0.9
# Jaro-Winkler similarity between 'chicken breasts' and 'chicken sausage': 0.9033333333333333
# Jaro-Winkler similarity between 'chicken breasts' and 'chicken tenders': 0.9033333333333333
# Jaro-Winkler similarity between 'chicken broth' and 'chicken broth low salt': 0.9181818181818182
# Jaro-Winkler similarity between 'chicken canned' and 'chicken spread canned': 0.9047619047619048
# Jaro-Winkler similarity between 'chicken cutlets' and 'chicken drumettes': 0.9108898944193061
# Jaro-Winkler similarity between 'chicken cutlets' and 'chicken legs': 0.9299999999999999
# Jaro-Winkler similarity between 'chicken cutlets' and 'chicken livers': 0.9038095238095238
# Jaro-Winkler similarity between 'chicken cutlets' and 'chicken tenders': 0.8933333333333334
# Jaro-Winkler similarity between 'chicken drumettes' and 'chicken drumsticks': 0.9059757236227824
# Jaro-Winkler similarity between 'chicken drumettes' and 'chicken tenders': 0.9228011204481793
# Jaro-Winkler similarity between 'chicken legs' and 'chicken livers': 0.9404761904761905
# Jaro-Winkler similarity between 'chicken legs' and 'chicken pieces': 0.9095238095238095
# Jaro-Winkler similarity between 'chicken legs' and 'chicken sausage': 0.9118181818181819
# Jaro-Winkler similarity between 'chicken legs' and 'chicken tenders': 0.9
# Jaro-Winkler similarity between 'chicken legs' and 'chicken wings': 0.9205128205128206
# Jaro-Winkler similarity between 'chicken livers' and 'chicken pieces': 0.9142857142857143
# Jaro-Winkler similarity between 'chicken livers' and 'chicken tenders': 0.9038095238095238
# Jaro-Winkler similarity between 'chicken livers' and 'chicken wings': 0.8967032967032967
# Jaro-Winkler similarity between 'chicken pieces' and 'chicken tenders': 0.9038095238095238
# Jaro-Winkler similarity between 'chicken pieces' and 'chicken wings': 0.8967032967032967
# Jaro-Winkler similarity between 'chile pepper' and 'green chili peppers': 0.9162004662004662
# Jaro-Winkler similarity between 'chile pepper' and 'red chili peppers': 0.9162004662004662
# Jaro-Winkler similarity between 'chile pods' and 'red chili pods': 0.96
# Jaro-Winkler similarity between 'chili bean sauce' and 'chili sauce': 0.9011363636363637
# Jaro-Winkler similarity between 'chili bean sauce' and 'green chile sauce': 0.9011363636363637
# Jaro-Winkler similarity between 'chili bean sauce' and 'red chili sauce': 0.9011363636363637
# Jaro-Winkler similarity between 'chili beans' and 'chili canned': 0.8914141414141414
# Jaro-Winkler similarity between 'chili pepper flakes' and 'green chili peppers': 0.9368421052631579
# Jaro-Winkler similarity between 'chili pepper flakes' and 'green chili peppers canned': 0.9034210526315789
# Jaro-Winkler similarity between 'chili pepper flakes' and 'red chili peppers': 0.9368421052631579
# Jaro-Winkler similarity between 'chili powder' and 'red chile powder': 0.9666666666666666
# Jaro-Winkler similarity between 'chili sauce' and 'green chile sauce': 0.9636363636363636
# Jaro-Winkler similarity between 'chili sauce' and 'red chili sauce': 1.0
# Jaro-Winkler similarity between 'chilli sambal' and 'green chili salsa': 0.8956643356643357
# Jaro-Winkler similarity between 'chipotle salsa' and 'green chili salsa': 0.9121212121212121
# Jaro-Winkler similarity between 'chipotle sauce' and 'green chile sauce': 0.95
# Jaro-Winkler similarity between 'chocolate' and 'chocolate bars': 0.9285714285714286
# Jaro-Winkler similarity between 'chocolate' and 'chocolate candies': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate' and 'chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate' and 'chocolate chunks': 0.9125
# Jaro-Winkler similarity between 'chocolate' and 'chocolate cookies': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate' and 'chocolate curls': 0.92
# Jaro-Winkler similarity between 'chocolate' and 'chocolate frosting': 0.9
# Jaro-Winkler similarity between 'chocolate' and 'chocolate ganache': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate' and 'chocolate ice cream': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate' and 'chocolate kisses': 0.9125
# Jaro-Winkler similarity between 'chocolate' and 'chocolate mints': 0.92
# Jaro-Winkler similarity between 'chocolate' and 'chocolate pieces': 0.9125
# Jaro-Winkler similarity between 'chocolate' and 'chocolate pudding': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate' and 'chocolate sprinkles': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate' and 'chocolate sweet': 0.92
# Jaro-Winkler similarity between 'chocolate' and 'chocolate syrup': 0.92
# Jaro-Winkler similarity between 'chocolate' and 'chocolate wafers': 0.9125
# Jaro-Winkler similarity between 'chocolate' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate bittersweet': 0.9095238095238095
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate candies': 0.9126050420168067
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate chips': 0.9038095238095238
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate chunks': 0.8946428571428571
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate curls': 0.9314285714285714
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate extract': 0.9285714285714286
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate frosting': 0.9047619047619048
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate kisses': 0.8946428571428571
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate mints': 0.9038095238095238
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate pieces': 0.8946428571428571
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate sweet': 0.9038095238095238
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate syrup': 0.9147619047619048
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate wafer cookies': 0.8987577639751553
# Jaro-Winkler similarity between 'chocolate bars' and 'chocolate wafers': 0.9482142857142858
# Jaro-Winkler similarity between 'chocolate bars' and 'white chocolate': 0.9285714285714286
# Jaro-Winkler similarity between 'chocolate bars' and 'white chocolate chips': 0.9038095238095238
# Jaro-Winkler similarity between 'chocolate bittersweet' and 'chocolate mints': 0.8971428571428571
# Jaro-Winkler similarity between 'chocolate bittersweet' and 'chocolate pieces': 0.894047619047619
# Jaro-Winkler similarity between 'chocolate bittersweet' and 'chocolate sweet': 0.9161904761904762
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate chips': 0.9262745098039216
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate chunks': 0.9154411764705882
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate cookies': 0.9294117647058824
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate covered peanuts': 0.891235294117647
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate covered raisins': 0.9124705882352941
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate curls': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate extract': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate ganache': 0.915126050420168
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate kisses': 0.9000565610859729
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate mints': 0.9108898944193061
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate pieces': 0.9254201680672269
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate pudding': 0.8904977375565611
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate sprinkles': 0.8977885891198584
# Jaro-Winkler similarity between 'chocolate candies' and 'chocolate wafers': 0.9154411764705882
# Jaro-Winkler similarity between 'chocolate candies' and 'white chocolate': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate candies' and 'white chocolate chips': 0.9262745098039216
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate chips semisweet': 0.92
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate chunks': 0.9358333333333334
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate cookies': 0.9262745098039216
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate curls': 0.92
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate extract': 0.92
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate ganache': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate kisses': 0.91
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate mints': 0.92
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate pieces': 0.9473809523809523
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate sprinkles': 0.8947908232118758
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate sweet': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate chips' and 'chocolate syrup': 0.9033333333333333
# Jaro-Winkler similarity between 'chocolate chips' and 'white chocolate': 0.92
# Jaro-Winkler similarity between 'chocolate chips' and 'white chocolate chips': 1.0
# Jaro-Winkler similarity between 'chocolate chips semisweet' and 'chocolate kisses': 0.9075
# Jaro-Winkler similarity between 'chocolate chips semisweet' and 'chocolate pieces': 0.903
# Jaro-Winkler similarity between 'chocolate chips semisweet' and 'chocolate sweet': 0.9066666666666666
# Jaro-Winkler similarity between 'chocolate chips semisweet' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate cookies': 0.9154411764705882
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate curls': 0.9358333333333334
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate extract': 0.9125
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate ganache': 0.9000565610859729
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate kisses': 0.9
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate mints': 0.91
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate pieces': 0.9
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate pudding': 0.8911764705882353
# Jaro-Winkler similarity between 'chocolate chunks' and 'chocolate syrup': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate chunks' and 'white chocolate': 0.9125
# Jaro-Winkler similarity between 'chocolate chunks' and 'white chocolate chips': 0.9358333333333334
# Jaro-Winkler similarity between 'chocolate cookie crumbs' and 'chocolate wafer crumbs': 0.9090469916556874
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate curls': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate extract': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate kisses': 0.9254201680672269
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate mints': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate pieces': 0.9254201680672269
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate sprinkles': 0.8977885891198584
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate wafer cookies': 0.9242966751918159
# Jaro-Winkler similarity between 'chocolate cookies' and 'chocolate wafers': 0.8911764705882353
# Jaro-Winkler similarity between 'chocolate cookies' and 'white chocolate': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate cookies' and 'white chocolate chips': 0.9262745098039216
# Jaro-Winkler similarity between 'chocolate covered peanuts' and 'chocolate covered raisins': 0.9264761904761905
# Jaro-Winkler similarity between 'chocolate covered peanuts' and 'chocolate pieces': 0.8941666666666667
# Jaro-Winkler similarity between 'chocolate covered raisins' and 'chocolate pieces': 0.8941666666666667
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate extract': 0.92
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate frosting': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate mints': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate pieces': 0.91
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate sprinkles': 0.8947908232118758
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate sweet': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate syrup': 0.9312820512820513
# Jaro-Winkler similarity between 'chocolate curls' and 'chocolate wafers': 0.91
# Jaro-Winkler similarity between 'chocolate curls' and 'white chocolate': 0.92
# Jaro-Winkler similarity between 'chocolate curls' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate frosting': 0.9
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate ganache': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate ice cream': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate kisses': 0.9125
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate mints': 0.92
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate pieces': 0.9125
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate pudding': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate sprinkles': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate sweet': 0.92
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate syrup': 0.92
# Jaro-Winkler similarity between 'chocolate extract' and 'chocolate wafers': 0.9125
# Jaro-Winkler similarity between 'chocolate extract' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate frosting' and 'chocolate fudge topping': 0.8919082125603864
# Jaro-Winkler similarity between 'chocolate frosting' and 'chocolate mints': 0.9136507936507937
# Jaro-Winkler similarity between 'chocolate frosting' and 'chocolate pudding': 0.8973856209150327
# Jaro-Winkler similarity between 'chocolate frosting' and 'chocolate sweet': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate frosting' and 'chocolate wafers': 0.9069444444444444
# Jaro-Winkler similarity between 'chocolate frosting' and 'white chocolate': 0.9
# Jaro-Winkler similarity between 'chocolate ganache' and 'chocolate wafers': 0.8911764705882353
# Jaro-Winkler similarity between 'chocolate ganache' and 'white chocolate': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate ganache' and 'white chocolate chips': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate ice cream' and 'chocolate pieces': 0.9080827067669173
# Jaro-Winkler similarity between 'chocolate ice cream' and 'chocolate wafer cookies': 0.8914793377305156
# Jaro-Winkler similarity between 'chocolate ice cream' and 'white chocolate': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate kisses' and 'chocolate mints': 0.91
# Jaro-Winkler similarity between 'chocolate kisses' and 'chocolate pieces': 0.9096153846153847
# Jaro-Winkler similarity between 'chocolate kisses' and 'chocolate sprinkles': 0.9187280701754386
# Jaro-Winkler similarity between 'chocolate kisses' and 'chocolate sweet': 0.91
# Jaro-Winkler similarity between 'chocolate kisses' and 'white chocolate': 0.9125
# Jaro-Winkler similarity between 'chocolate kisses' and 'white chocolate chips': 0.91
# Jaro-Winkler similarity between 'chocolate mints' and 'chocolate pieces': 0.91
# Jaro-Winkler similarity between 'chocolate mints' and 'chocolate pudding': 0.9011764705882354
# Jaro-Winkler similarity between 'chocolate mints' and 'chocolate sprinkles': 0.8947908232118758
# Jaro-Winkler similarity between 'chocolate mints' and 'chocolate sweet': 0.9033333333333333
# Jaro-Winkler similarity between 'chocolate mints' and 'chocolate syrup': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate mints' and 'white chocolate': 0.92
# Jaro-Winkler similarity between 'chocolate mints' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate pudding': 0.8911764705882353
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate sprinkles': 0.893796992481203
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate sweet': 0.9204487179487179
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate syrup': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate wafer cookies': 0.9046014492753623
# Jaro-Winkler similarity between 'chocolate pieces' and 'chocolate wafers': 0.9
# Jaro-Winkler similarity between 'chocolate pieces' and 'white chocolate': 0.9125
# Jaro-Winkler similarity between 'chocolate pieces' and 'white chocolate chips': 0.9473809523809523
# Jaro-Winkler similarity between 'chocolate pudding' and 'white chocolate': 0.9058823529411765
# Jaro-Winkler similarity between 'chocolate sauce' and 'chocolate wafer crumbs': 0.8996536796536796
# Jaro-Winkler similarity between 'chocolate sprinkles' and 'chocolate syrup': 0.8947908232118758
# Jaro-Winkler similarity between 'chocolate sprinkles' and 'white chocolate': 0.8947368421052632
# Jaro-Winkler similarity between 'chocolate sprinkles' and 'white chocolate chips': 0.8947908232118758
# Jaro-Winkler similarity between 'chocolate sweet' and 'chocolate syrup': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate sweet' and 'chocolate wafers': 0.9204487179487179
# Jaro-Winkler similarity between 'chocolate sweet' and 'white chocolate': 0.92
# Jaro-Winkler similarity between 'chocolate sweet' and 'white chocolate chips': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate syrup' and 'chocolate wafers': 0.8933333333333334
# Jaro-Winkler similarity between 'chocolate syrup' and 'white chocolate': 0.92
# Jaro-Winkler similarity between 'chocolate syrup' and 'white chocolate chips': 0.9033333333333333
# Jaro-Winkler similarity between 'chocolate wafer cookies' and 'chocolate wafers': 0.9391304347826087
# Jaro-Winkler similarity between 'chocolate wafers' and 'white chocolate': 0.9125
# Jaro-Winkler similarity between 'cilantro' and 'cilantro root': 0.9230769230769231
# Jaro-Winkler similarity between 'cilantro' and 'cilantro stems': 0.9142857142857143
# Jaro-Winkler similarity between 'cilantro root' and 'cilantro stems': 0.8967032967032967
# Jaro-Winkler similarity between 'cinnamon' and 'cinnamon sticks': 0.9066666666666666
# Jaro-Winkler similarity between 'cinnamon' and 'cinnamon sugar': 0.9142857142857143
# Jaro-Winkler similarity between 'clover honey' and 'cloves whole': 0.9
# Jaro-Winkler similarity between 'cloves' and 'cloves whole': 0.9
# Jaro-Winkler similarity between 'coconut' and 'coconut cream': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut' and 'coconut sugar': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut' and 'coconut water': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut cream' and 'coconut extract': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut cream' and 'coconut water': 0.9202797202797203
# Jaro-Winkler similarity between 'coconut extract' and 'coconut sugar': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut extract' and 'coconut water': 0.9076923076923077
# Jaro-Winkler similarity between 'coconut flour' and 'coconut oil': 0.9156643356643357
# Jaro-Winkler similarity between 'coconut milk' and 'coconut oil': 0.9484848484848484
# Jaro-Winkler similarity between 'coconut shredded desiccated' and 'coconut shredded unsweetened desiccated': 0.9088319088319089
# Jaro-Winkler similarity between 'coconut sugar' and 'coconut water': 0.9076923076923077
# Jaro-Winkler similarity between 'coleslaw' and 'coleslaw mix': 0.9333333333333333
# Jaro-Winkler similarity between 'corander' and 'coriander root': 0.9
# Jaro-Winkler similarity between 'coriander' and 'coriander root': 0.9285714285714286
# Jaro-Winkler similarity between 'corn chips' and 'corn cobs': 0.8955555555555555
# Jaro-Winkler similarity between 'corn chips' and 'cornichons': 0.895
# Jaro-Winkler similarity between 'corn cobs' and 'cornichons': 0.8955555555555555
# Jaro-Winkler similarity between 'corn grits' and 'corn niblets': 0.8933333333333334
# Jaro-Winkler similarity between 'corn syrup dark' and 'corn syrup white karo': 0.9473809523809523
# Jaro-Winkler similarity between 'cottage cheese' and 'cottage cheese lowfat': 0.9333333333333333
# Jaro-Winkler similarity between 'cracker meal' and 'crackers': 0.8916666666666667
# Jaro-Winkler similarity between 'cranberries' and 'cranberries dried': 0.9294117647058824
# Jaro-Winkler similarity between 'cranberries' and 'cranberry beans': 0.9151515151515152
# Jaro-Winkler similarity between 'cranberries' and 'cranberry juice': 0.9151515151515152
# Jaro-Winkler similarity between 'cranberry beans' and 'cranberry jelly': 0.8933333333333334
# Jaro-Winkler similarity between 'cranberry beans' and 'cranberry juice': 0.8933333333333334
# Jaro-Winkler similarity between 'cranberry jelly' and 'cranberry juice': 0.92
# Jaro-Winkler similarity between 'cranberry jelly' and 'strawberry jelly': 0.8930555555555556
# Jaro-Winkler similarity between 'cranberry juice' and 'raspberry juice': 0.9111111111111111
# Jaro-Winkler similarity between 'cranberry sauce' and 'cranraspberry sauce': 0.9045614035087719
# Jaro-Winkler similarity between 'cranberry sauce' and 'raspberry sauce': 0.9111111111111111
# Jaro-Winkler similarity between 'cream cheese' and 'cream cheese frosting': 0.9142857142857143
# Jaro-Winkler similarity between 'cream cheese' and 'cream cheese nonfat': 0.9263157894736842
# Jaro-Winkler similarity between 'cream cheese' and 'cream cheese reducedfat': 0.9043478260869565
# Jaro-Winkler similarity between 'cream cheese frosting' and 'cream cheese nonfat': 0.9290874244434615
# Jaro-Winkler similarity between 'cream cheese nonfat' and 'cream cheese reducedfat': 0.9075514874141876
# Jaro-Winkler similarity between 'creme de banana' and 'creme de cacao': 0.9038095238095238
# Jaro-Winkler similarity between 'creme de cacao' and 'creme de cassis': 0.9038095238095238
# Jaro-Winkler similarity between 'cupcake papers' and 'cupcakes': 0.9142857142857143
# Jaro-Winkler similarity between 'curry stock' and 'green curry paste': 0.890909090909091
# Jaro-Winkler similarity between 'curry stock' and 'red curry paste': 0.890909090909091
# Jaro-Winkler similarity between 'date sugar' and 'dates': 0.9
# Jaro-Winkler similarity between 'deli ham' and 'deviled ham': 0.893939393939394
# Jaro-Winkler similarity between 'dill pickle chips' and 'dill pickle liquid': 0.8973856209150327
# Jaro-Winkler similarity between 'dill seed' and 'dill weed': 0.9555555555555556
# Jaro-Winkler similarity between 'dill weed' and 'dill weed dried': 0.92
# Jaro-Winkler similarity between 'dill weed' and 'dill weed fresh': 0.92
# Jaro-Winkler similarity between 'dill weed dried' and 'dill weed fresh': 0.92
# Jaro-Winkler similarity between 'egg beaters' and 'eggbeaters': 0.9787878787878788
# Jaro-Winkler similarity between 'enchilada sauce' and 'green enchilada sauce': 1.0
# Jaro-Winkler similarity between 'english muffins' and 'muffin mix': 0.8914285714285715
# Jaro-Winkler similarity between 'english mustard' and 'mustard greens': 0.9
# Jaro-Winkler similarity between 'fenugreek' and 'fenugreek leaves': 0.9125
# Jaro-Winkler similarity between 'file powder' and 'red chile powder': 0.914141414141414
# Jaro-Winkler similarity between 'fish' and 'fish cod': 0.9
# Jaro-Winkler similarity between 'flour tortillas' and 'flour tortillas inch': 0.95
# Jaro-Winkler similarity between 'flour tortillas' and 'flour tortillas whole wheat': 0.9111111111111111
# Jaro-Winkler similarity between 'flour tortillas inch' and 'flour tortillas whole wheat': 0.8959259259259259
# Jaro-Winkler similarity between 'fontina cheese' and 'fortina cheese': 0.9413919413919414
# Jaro-Winkler similarity between 'french bread' and 'french fries': 0.9
# Jaro-Winkler similarity between 'french fried onions' and 'french fries': 0.9263157894736842
# Jaro-Winkler similarity between 'french fries' and 'french rolls': 0.9
# Jaro-Winkler similarity between 'fruit' and 'fruit jam': 0.9111111111111111
# Jaro-Winkler similarity between 'fruit' and 'fruit mix': 0.9111111111111111
# Jaro-Winkler similarity between 'fruit' and 'fruit roll': 0.9
# Jaro-Winkler similarity between 'fruit cake mixture' and 'fruit mix': 0.9
# Jaro-Winkler similarity between 'fruit jam' and 'fruit mix': 0.9111111111111111
# Jaro-Winkler similarity between 'fruit relish' and 'fruit roll': 0.8933333333333334
# Jaro-Winkler similarity between 'garlic' and 'garlic bread': 0.9
# Jaro-Winkler similarity between 'garlic' and 'garlic bulb': 0.9090909090909091
# Jaro-Winkler similarity between 'garlic' and 'garlic chives': 0.8923076923076924
# Jaro-Winkler similarity between 'garlic' and 'garlic cloves': 0.8923076923076924
# Jaro-Winkler similarity between 'garlic' and 'garlic puree': 0.9
# Jaro-Winkler similarity between 'garlic' and 'garlic scapes': 0.8923076923076924
# Jaro-Winkler similarity between 'garlic bread' and 'garlic puree': 0.9
# Jaro-Winkler similarity between 'garlic chives' and 'garlic cloves': 0.9384615384615385
# Jaro-Winkler similarity between 'garlic paste' and 'garlic salt': 0.9284848484848485
# Jaro-Winkler similarity between 'garlic paste' and 'garlic sauce': 0.9133333333333333
# Jaro-Winkler similarity between 'garlic salt' and 'garlic sauce': 0.9136363636363637
# Jaro-Winkler similarity between 'gelatin flavored' and 'gelatin flavored sugarfree': 0.9230769230769231
# Jaro-Winkler similarity between 'gelatin flavored' and 'gelatin unflavored': 0.9777777777777777
# Jaro-Winkler similarity between 'ginger' and 'ginger ale': 0.92
# Jaro-Winkler similarity between 'ginger' and 'ginger juice': 0.9
# Jaro-Winkler similarity between 'ginger' and 'ginger root': 0.9090909090909091
# Jaro-Winkler similarity between 'ginger' and 'ginger slices': 0.8923076923076924
# Jaro-Winkler similarity between 'ginger ale' and 'ginger juice': 0.8933333333333334
# Jaro-Winkler similarity between 'ginger ale' and 'ginger slices': 0.9184615384615384
# Jaro-Winkler similarity between 'ginger juice' and 'ginger slices': 0.9205128205128206
# Jaro-Winkler similarity between 'ginger slices' and 'ginger snap cookies': 0.8942645074224022
# Jaro-Winkler similarity between 'ginger snap cookies' and 'gingersnap cookies': 0.967251461988304
# Jaro-Winkler similarity between 'graham cracker crumbs' and 'graham wafer crumbs': 0.9055580126787557
# Jaro-Winkler similarity between 'graham cracker pie crust' and 'graham crackerswafers': 0.8918067226890756
# Jaro-Winkler similarity between 'grape jelly' and 'grape juice': 0.890909090909091
# Jaro-Winkler similarity between 'grape jelly' and 'white grape juice': 0.890909090909091
# Jaro-Winkler similarity between 'grape juice' and 'grapefruit juice': 0.9011363636363637
# Jaro-Winkler similarity between 'grape juice' and 'white grape juice': 1.0
# Jaro-Winkler similarity between 'grape nuts cereal' and 'grapenuts': 0.9058823529411765
# Jaro-Winkler similarity between 'grapefruit' and 'grapefruit juice': 0.925
# Jaro-Winkler similarity between 'grapefruit' and 'grapefruit peel': 0.9333333333333333
# Jaro-Winkler similarity between 'grapefruit juice' and 'grapefruit peel': 0.91
# Jaro-Winkler similarity between 'grapefruit juice' and 'white grape juice': 0.9011363636363637
# Jaro-Winkler similarity between 'gravy' and 'gravy mix brown': 0.9111111111111111
# Jaro-Winkler similarity between 'green chile sauce' and 'red chili sauce': 0.9636363636363636
# Jaro-Winkler similarity between 'green chili peppers' and 'green chili peppers canned': 0.9299999999999999
# Jaro-Winkler similarity between 'green chili peppers' and 'red chili peppers': 1.0
# Jaro-Winkler similarity between 'green chili peppers canned' and 'red chili peppers': 0.9299999999999999
# Jaro-Winkler similarity between 'green curry paste' and 'red curry paste': 1.0
# Jaro-Winkler similarity between 'green salsa' and 'salsa verde': 0.890909090909091
# Jaro-Winkler similarity between 'green tomatoes' and 'tomato juice': 0.8916666666666667
# Jaro-Winkler similarity between 'green tomatoes' and 'tomato soup': 0.9022727272727272
# Jaro-Winkler similarity between 'green tomatoes' and 'tomato wedges': 0.9230769230769231
# Jaro-Winkler similarity between 'green tomatoes' and 'tomatoes canned': 0.9066666666666666
# Jaro-Winkler similarity between 'ground beef' and 'ground beef extra lean': 0.9
# Jaro-Winkler similarity between 'ground beef' and 'ground beef lean': 0.9375
# Jaro-Winkler similarity between 'ground beef' and 'ground buffalo': 0.8922077922077922
# Jaro-Winkler similarity between 'ground beef' and 'ground lamb': 0.890909090909091
# Jaro-Winkler similarity between 'ground beef' and 'ground meat': 0.890909090909091
# Jaro-Winkler similarity between 'ground beef' and 'ground veal': 0.890909090909091
# Jaro-Winkler similarity between 'ground beef extra lean' and 'ground beef lean': 0.9329545454545455
# Jaro-Winkler similarity between 'ground beef lean' and 'ground flax seed': 0.8942307692307693
# Jaro-Winkler similarity between 'ground buffalo' and 'ground lamb': 0.9046753246753247
# Jaro-Winkler similarity between 'ground buffalo' and 'ground veal': 0.8922077922077922
# Jaro-Winkler similarity between 'ground ham' and 'ground lamb': 0.9436363636363637
# Jaro-Winkler similarity between 'ground ham' and 'ground meat': 0.9214141414141415
# Jaro-Winkler similarity between 'ground ham' and 'ground veal': 0.9054545454545454
# Jaro-Winkler similarity between 'ground lamb' and 'ground meat': 0.905050505050505
# Jaro-Winkler similarity between 'ground lamb' and 'ground veal': 0.905050505050505
# Jaro-Winkler similarity between 'ground meat' and 'ground nuts': 0.890909090909091
# Jaro-Winkler similarity between 'ground meat' and 'ground veal': 0.9272727272727274
# Jaro-Winkler similarity between 'ground pork' and 'ground turkey': 0.9020979020979021
# Jaro-Winkler similarity between 'ham base' and 'ham bone': 0.9
# Jaro-Winkler similarity between 'ham base' and 'ham steak': 0.901984126984127
# Jaro-Winkler similarity between 'hamburger buns' and 'hamburgers': 0.9428571428571428
# Jaro-Winkler similarity between 'hamburger patties' and 'hamburgers': 0.9176470588235295
# Jaro-Winkler similarity between 'hawaiian fish' and 'hawaiian punch': 0.8967032967032967
# Jaro-Winkler similarity between 'hemp seed oil' and 'hemp seeds': 0.9184615384615384
# Jaro-Winkler similarity between 'herb stuffing cubes' and 'herb stuffing mix': 0.9120743034055727
# Jaro-Winkler similarity between 'herbal salt' and 'herbal salt substitute': 0.9
# Jaro-Winkler similarity between 'herring' and 'herring roe': 0.9272727272727272
# Jaro-Winkler similarity between 'honeydew melon' and 'honeydew melon balls': 0.9400000000000001
# Jaro-Winkler similarity between 'horseradish' and 'horseradish root': 0.9375
# Jaro-Winkler similarity between 'hot bean sauce' and 'hot jalapeno sauce': 0.8993894993894994
# Jaro-Winkler similarity between 'hot chili peppers' and 'hot chili pod': 0.8986425339366516
# Jaro-Winkler similarity between 'hot chili peppers' and 'hot red chiles': 0.893048128342246
# Jaro-Winkler similarity between 'hot chili peppers' and 'red hot chili pepper dried': 0.9336898395721925
# Jaro-Winkler similarity between 'hot chili pod' and 'red hot chili pepper dried': 0.8937062937062936
# Jaro-Winkler similarity between 'hot pepper sesame oil' and 'red hot pepper sauce': 0.894047619047619
# Jaro-Winkler similarity between 'imitation bacon bits' and 'imitation crab': 0.9003296703296704
# Jaro-Winkler similarity between 'instant coffee' and 'instant coffee espresso': 0.9217391304347826
# Jaro-Winkler similarity between 'instant pudding mix' and 'instant pudding mix chocolate': 0.9310344827586207
# Jaro-Winkler similarity between 'instant pudding mix' and 'instant pudding mix pistachio': 0.9310344827586207
# Jaro-Winkler similarity between 'instant pudding mix' and 'instant pudding mix vanilla': 0.9407407407407408
# Jaro-Winkler similarity between 'instant pudding mix chocolate' and 'instant pudding mix pistachio': 0.9288275862068965
# Jaro-Winkler similarity between 'instant pudding mix chocolate' and 'instant pudding mix vanilla': 0.9055961918030884
# Jaro-Winkler similarity between 'instant pudding mix pistachio' and 'instant pudding mix vanilla': 0.9055961918030884
# Jaro-Winkler similarity between 'italian bread shell' and 'italian herbs': 0.9060728744939271
# Jaro-Winkler similarity between 'italian cheese' and 'italian herbs': 0.9263736263736264
# Jaro-Winkler similarity between 'italian herbs' and 'italian parsley': 0.8977156177156177
# Jaro-Winkler similarity between 'italian sausage' and 'italian seasoning': 0.8955052790346908
# Jaro-Winkler similarity between 'jelly' and 'jelly beans': 0.890909090909091
# Jaro-Winkler similarity between 'juice' and 'v juice': 0.9047619047619048
# Jaro-Winkler similarity between 'kaffir lime' and 'kaffir lime leaves': 0.9222222222222222
# Jaro-Winkler similarity between 'kidney beans canned' and 'red kidney beans': 0.9263157894736842
# Jaro-Winkler similarity between 'kidney beans canned' and 'white kidney beans canned': 1.0
# Jaro-Winkler similarity between 'lamb shoulder' and 'lamb shoulder chops': 0.9368421052631579
# Jaro-Winkler similarity between 'lemon' and 'lemon balm': 0.9
# Jaro-Winkler similarity between 'lemon' and 'lemon curd': 0.9
# Jaro-Winkler similarity between 'lemon' and 'lemon juice': 0.890909090909091
# Jaro-Winkler similarity between 'lemon' and 'lemon slice': 0.890909090909091
# Jaro-Winkler similarity between 'lemon' and 'lemon thyme': 0.890909090909091
# ...
# Jaro-Winkler similarity between 'salad dressing french' and 'salad dressing russian': 0.9164502164502164
# Jaro-Winkler similarity between 'salad dressing french' and 'salad dressing vinaigrette': 0.8987789987789988
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing italian lowfat': 0.9517241379310345
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing lowfat': 0.923953823953824
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing mayonnaise style': 0.9073453428292138
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing mix italian': 0.9510489510489512
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing mix ranch': 0.9136363636363637
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing russian': 0.9272727272727274
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing thousand island': 0.9023376623376623
# Jaro-Winkler similarity between 'salad dressing italian' and 'salad dressing vinaigrette': 0.9256643356643357
# Jaro-Winkler similarity between 'salad dressing italian lowfat' and 'salad dressing lowfat': 0.916256157635468
# Jaro-Winkler similarity between 'salad dressing italian lowfat' and 'salad dressing mix italian': 0.9094568100565101
# Jaro-Winkler similarity between 'salad dressing italian lowfat' and 'salad dressing vinaigrette': 0.8968422382215486
# Jaro-Winkler similarity between 'salad dressing lowfat' and 'salad dressing mayonnaise style': 0.8930067103241977
# Jaro-Winkler similarity between 'salad dressing lowfat' and 'salad dressing mix italian': 0.8987789987789988
# Jaro-Winkler similarity between 'salad dressing lowfat' and 'salad dressing russian': 0.8978354978354979
# Jaro-Winkler similarity between 'salad dressing lowfat' and 'salad dressing thousand island': 0.8970927318295739
# Jaro-Winkler similarity between 'salad dressing lowfat' and 'salad dressing vinaigrette': 0.8926739926739927
# Jaro-Winkler similarity between 'salad dressing mayonnaise style' and 'salad dressing mix italian': 0.8992232171755313
# Jaro-Winkler similarity between 'salad dressing mayonnaise style' and 'salad dressing russian': 0.8908504398826979
# Jaro-Winkler similarity between 'salad dressing mayonnaise style' and 'salad dressing thousand island': 0.9026137303556659
# Jaro-Winkler similarity between 'salad dressing mix italian' and 'salad dressing mix ranch': 0.9365384615384615
# Jaro-Winkler similarity between 'salad dressing mix italian' and 'salad dressing russian': 0.9020979020979021
# Jaro-Winkler similarity between 'salad dressing mix ranch' and 'salad dressing russian': 0.9205342902711323
# Jaro-Winkler similarity between 'salad dressing mix ranch' and 'salad dressing vinaigrette': 0.8939608636977058
# Jaro-Winkler similarity between 'salad dressing russian' and 'salad dressing thousand island': 0.9118614718614719
# Jaro-Winkler similarity between 'salad dressing russian' and 'salad dressing vinaigrette': 0.9083548030916452
# Jaro-Winkler similarity between 'salmon' and 'salmon steaks': 0.8923076923076924
# Jaro-Winkler similarity between 'salsa' and 'salsa verde': 0.890909090909091
# Jaro-Winkler similarity between 'salt and black pepper' and 'salt and cayenne pepper': 0.9141304347826087
# Jaro-Winkler similarity between 'salt and black pepper' and 'salt and white pepper': 1.0
# Jaro-Winkler similarity between 'salt and cayenne pepper' and 'salt and white pepper': 0.9141304347826087
# Jaro-Winkler similarity between 'sausage' and 'sausage bulk': 0.9166666666666667
# Jaro-Winkler similarity between 'sausage' and 'sausage casing': 0.9
# Jaro-Winkler similarity between 'sausage' and 'sausage links': 0.9076923076923077
# Jaro-Winkler similarity between 'sausage' and 'sausage meat': 0.9166666666666667
# Jaro-Winkler similarity between 'sausage bulk' and 'sausage links': 0.9205128205128206
# Jaro-Winkler similarity between 'sausage casing' and 'sausage links': 0.9081918081918082
# Jaro-Winkler similarity between 'sauterne' and 'sauterne wine': 0.9230769230769231
# Jaro-Winkler similarity between 'seasoning' and 'seasoning mix': 0.9384615384615385
# Jaro-Winkler similarity between 'seranos chilies' and 'serrano chiles': 0.9522222222222222
# Jaro-Winkler similarity between 'sherry' and 'sherry wine': 0.9090909090909091
# Jaro-Winkler similarity between 'shrimp' and 'shrimp cooked': 0.8923076923076924
# Jaro-Winkler similarity between 'shrimp' and 'shrimp dried': 0.9
# Jaro-Winkler similarity between 'shrimp' and 'shrimp puffs': 0.9
# Jaro-Winkler similarity between 'smoked ham' and 'smoked ham shank': 0.925
# Jaro-Winkler similarity between 'smoked ham' and 'smoked meat': 0.9214141414141415
# Jaro-Winkler similarity between 'smoked ham' and 'smoked salmon': 0.9184615384615384
# Jaro-Winkler similarity between 'soba noodles' and 'soup noodles': 0.9111111111111112
# Jaro-Winkler similarity between 'soup cream of asparagus' and 'soup cream of cheddar': 0.891511387163561
# Jaro-Winkler similarity between 'soup cream of broccoli' and 'soup cream of celery': 0.9127807486631015
# Jaro-Winkler similarity between 'soup cream of broccoli' and 'soup cream of chicken': 0.9046855105678635
# Jaro-Winkler similarity between 'soup cream of broccoli' and 'soup cream of onion': 0.9217281170841541
# Jaro-Winkler similarity between 'soup cream of broccoli' and 'soup cream of potato': 0.9054545454545454
# Jaro-Winkler similarity between 'soup cream of broccoli' and 'soup cream of tomato': 0.9054545454545454
# Jaro-Winkler similarity between 'soup cream of celery' and 'soup cream of cheddar': 0.9319047619047619
# Jaro-Winkler similarity between 'soup cream of celery' and 'soup cream of chicken': 0.9123809523809524
# Jaro-Winkler similarity between 'soup cream of cheddar' and 'soup cream of chicken': 0.9238095238095239
# Jaro-Winkler similarity between 'soup cream of cheddar' and 'soup cream of potato': 0.8928571428571429
# Jaro-Winkler similarity between 'soup cream of cheddar' and 'soup cream of tomato': 0.8928571428571429
# Jaro-Winkler similarity between 'soup cream of chicken' and 'soup cream of onion': 0.9083020050125313
# Jaro-Winkler similarity between 'soup cream of onion' and 'soup cream of potato': 0.9284210526315789
# Jaro-Winkler similarity between 'soup cream of onion' and 'soup cream of tomato': 0.9284210526315789
# Jaro-Winkler similarity between 'soup cream of onion' and 'soup french onion': 0.9076986584107327
# Jaro-Winkler similarity between 'soup cream of potato' and 'soup cream of tomato': 0.9694736842105263
# Jaro-Winkler similarity between 'soup mix vegetable dry' and 'soup vegetable mix': 0.896969696969697
# Jaro-Winkler similarity between 'soup noodles' and 'soup ramen noodles': 0.9
# Jaro-Winkler similarity between 'sour cream' and 'sour cream light': 0.925
# Jaro-Winkler similarity between 'sour cream' and 'sour cream nonfat': 0.9176470588235295
# Jaro-Winkler similarity between 'sour cream light' and 'sour cream nonfat': 0.8911764705882353
# Jaro-Winkler similarity between 'sour milk' and 'soy milk': 0.9074074074074073
# Jaro-Winkler similarity between 'sourdough' and 'sourdough bread': 0.92
# Jaro-Winkler similarity between 'sourdough' and 'sourdough starter': 0.9058823529411765
# Jaro-Winkler similarity between 'sourdough bread' and 'sourdough starter': 0.9108898944193061
# Jaro-Winkler similarity between 'soy milk' and 'soy oil': 0.9214285714285715
# Jaro-Winkler similarity between 'soy sauce dark' and 'soy sauce tamari': 0.9214285714285715
# Jaro-Winkler similarity between 'soy sauce light' and 'soy sauce tamari': 0.8933333333333334
# Jaro-Winkler similarity between 'spaghetti' and 'spaghetti cooked': 0.9125
# Jaro-Winkler similarity between 'spaghetti' and 'spaghetti squash': 0.9125
# Jaro-Winkler similarity between 'spinach' and 'spinach dip': 0.9272727272727272
# Jaro-Winkler similarity between 'spinach' and 'spinach frozen': 0.9
# Jaro-Winkler similarity between 'split peas' and 'yellow split peas': 1.0
# Jaro-Winkler similarity between 'sponge' and 'sponge cake': 0.9090909090909091
# Jaro-Winkler similarity between 'strawberries' and 'strawberry glaze': 0.8916666666666667
# Jaro-Winkler similarity between 'strawberries' and 'strawberry ice cream': 0.8933333333333334
# Jaro-Winkler similarity between 'strawberries' and 'strawberry jelly': 0.8916666666666667
# Jaro-Winkler similarity between 'strawberries' and 'strawberry preserves': 0.8933333333333334
# Jaro-Winkler similarity between 'strawberries' and 'strawberry soda': 0.9
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry glaze': 0.925
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry ice cream': 0.9
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry jam': 0.9428571428571428
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry jelly': 0.925
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry preserves': 0.9
# Jaro-Winkler similarity between 'strawberry extract' and 'strawberry soda': 0.9333333333333333
# Jaro-Winkler similarity between 'strawberry glaze' and 'strawberry jam': 0.9214285714285715
# Jaro-Winkler similarity between 'strawberry glaze' and 'strawberry jelly': 0.9096153846153847
# Jaro-Winkler similarity between 'strawberry glaze' and 'strawberry soda': 0.91
# Jaro-Winkler similarity between 'strawberry ice cream' and 'strawberry jam': 0.9157142857142857
# Jaro-Winkler similarity between 'strawberry jam' and 'strawberry jelly': 0.9214285714285715
# Jaro-Winkler similarity between 'strawberry jam' and 'strawberry soda': 0.9314285714285714
# Jaro-Winkler similarity between 'stuffing' and 'stuffing mix': 0.9333333333333333
# Jaro-Winkler similarity between 'sugar' and 'sugar cane': 0.9
# Jaro-Winkler similarity between 'sweet and sour sauce' and 'sweet bean sauce': 0.9007142857142857
# Jaro-Winkler similarity between 'sweet bell peppers' and 'sweet red bell peppers': 0.967251461988304
# Jaro-Winkler similarity between 'sweet bell peppers' and 'sweet yellow bell peppers': 0.967251461988304
# Jaro-Winkler similarity between 'sweet cream base' and 'sweet peas': 0.8925
# Jaro-Winkler similarity between 'sweet peas' and 'sweet relish': 0.8933333333333334
# Jaro-Winkler similarity between 'sweet red bell peppers' and 'sweet yellow bell peppers': 1.0
# Jaro-Winkler similarity between 'taco shells' and 'tart shells': 0.9030303030303031
# Jaro-Winkler similarity between 'tamarind' and 'tamarind juice': 0.9142857142857143
# Jaro-Winkler similarity between 'tangerine juice' and 'tangerine peel': 0.9038095238095238
# Jaro-Winkler similarity between 'tangerine juice' and 'tangerines': 0.9
# Jaro-Winkler similarity between 'tangerine peel' and 'tangerines': 0.9085714285714286
# Jaro-Winkler similarity between 'taro leaves' and 'tarragon leaves': 0.8953535353535353
# Jaro-Winkler similarity between 'taro leaves' and 'tea leaves': 0.9154545454545455
# Jaro-Winkler similarity between 'thai chile sauce' and 'thai chili paste': 0.9096153846153847
# Jaro-Winkler similarity between 'tomato juice' and 'tomatoe juice': 0.9346153846153846
# Jaro-Winkler similarity between 'tomato juice' and 'tomatoes': 0.8916666666666667
# Jaro-Winkler similarity between 'tomato juice' and 'yellow tomatoes': 0.8916666666666667
# Jaro-Winkler similarity between 'tomato paste' and 'tomato sauce': 0.9133333333333333
# Jaro-Winkler similarity between 'tomato soup' and 'tomatoes': 0.9022727272727272
# Jaro-Winkler similarity between 'tomato soup' and 'yellow tomatoes': 0.9022727272727272
# Jaro-Winkler similarity between 'tomato wedges' and 'tomatoes': 0.9230769230769231
# Jaro-Winkler similarity between 'tomato wedges' and 'yellow tomatoes': 0.9230769230769231
# Jaro-Winkler similarity between 'tomatoes' and 'tomatoes canned': 0.9066666666666666
# Jaro-Winkler similarity between 'tomatoes canned' and 'tomatoes canned crushed': 0.9304347826086957
# Jaro-Winkler similarity between 'tomatoes canned' and 'tomatoes canned whole peeled': 0.9071428571428571
# Jaro-Winkler similarity between 'tomatoes canned' and 'tomatoes canned with juice': 0.9153846153846154
# Jaro-Winkler similarity between 'tomatoes canned' and 'tomatoes stewed canned': 0.8963636363636363
# Jaro-Winkler similarity between 'tomatoes canned' and 'yellow tomatoes': 0.9066666666666666
# Jaro-Winkler similarity between 'tomatoes canned crushed' and 'tomatoes canned whole peeled': 0.9009316770186335
# Jaro-Winkler similarity between 'tomatoes canned crushed' and 'tomatoes canned with juice': 0.9177591973244147
# Jaro-Winkler similarity between 'tomatoes canned crushed' and 'tomatoes stewed canned': 0.8958394008737258
# Jaro-Winkler similarity between 'turkey' and 'turkey bacon': 0.9
# Jaro-Winkler similarity between 'turkey' and 'turkey breast': 0.8923076923076924
# Jaro-Winkler similarity between 'turkey' and 'turkey ham': 0.92
# Jaro-Winkler similarity between 'turkey' and 'turkey legs': 0.9090909090909091
# Jaro-Winkler similarity between 'turkey' and 'turkey liver': 0.9
# Jaro-Winkler similarity between 'turkey' and 'turkey meat': 0.9090909090909091
# Jaro-Winkler similarity between 'turkey' and 'turkey wings': 0.9
# Jaro-Winkler similarity between 'turkey bacon' and 'turkey ham': 0.8933333333333334
# Jaro-Winkler similarity between 'turkey breast' and 'turkey breast fillets': 0.9238095238095239
# Jaro-Winkler similarity between 'turkey breast' and 'turkey legs': 0.9020979020979021
# Jaro-Winkler similarity between 'turkey breast' and 'turkey meat': 0.9356643356643356
# Jaro-Winkler similarity between 'turkey ham' and 'turkey meat': 0.9214141414141415
# Jaro-Winkler similarity between 'turkey italian sausage' and 'turkey sausage': 0.8987012987012987
# Jaro-Winkler similarity between 'turkey legs' and 'turkey liver': 0.9136363636363637
# Jaro-Winkler similarity between 'turkey legs' and 'turkey meat': 0.890909090909091
# Jaro-Winkler similarity between 'turkey legs' and 'turkey sausage': 0.9046753246753247
# Jaro-Winkler similarity between 'turkey legs' and 'turkey wings': 0.9136363636363637
# Jaro-Winkler similarity between 'vanilla bean' and 'vanilla extract': 0.9166666666666667
# Jaro-Winkler similarity between 'vanilla custard' and 'vanilla extract': 0.8933333333333334
# Jaro-Winkler similarity between 'vanilla custard' and 'vanilla sugar': 0.9279487179487179
# Jaro-Winkler similarity between 'vanilla extract' and 'vanilla sugar': 0.9076923076923077
# Jaro-Winkler similarity between 'vanilla extract' and 'vanilla wafers': 0.9
# Jaro-Winkler similarity between 'vanilla extract' and 'vanilla yogurt': 0.9
# Jaro-Winkler similarity between 'vanilla frosting' and 'vanilla wafers': 0.8946428571428571
# Jaro-Winkler similarity between 'vanilla sugar' and 'vanilla wafers': 0.9081918081918082
# Jaro-Winkler similarity between 'vanilla sugar' and 'vanilla yogurt': 0.9081918081918082
# Jaro-Winkler similarity between 'vegetable dip' and 'vegetable soup mix dry': 0.9027972027972029
# Jaro-Winkler similarity between 'vegetable dip' and 'vegetables': 0.9184615384615384
# Jaro-Winkler similarity between 'vegetable oil' and 'vegetable shortening': 0.9046153846153846
# Jaro-Winkler similarity between 'vegetable oil' and 'vegetable stock': 0.9158974358974359
# Jaro-Winkler similarity between 'vegetable soup mix dry' and 'vegetables': 0.890909090909091
# Jaro-Winkler similarity between 'vegetable stock' and 'vegetable stock cubes': 0.9428571428571428
# Jaro-Winkler similarity between 'venison' and 'venison chops': 0.9076923076923077
# Jaro-Winkler similarity between 'water chestnuts' and 'watercress': 0.9
# Jaro-Winkler similarity between 'white chocolate' and 'white chocolate chips': 0.92
# Jaro-Winkler similarity between 'wholewheat flour' and 'wholewheat pastry flour': 0.9141304347826087
# Jaro-Winkler similarity between 'yeast cakes' and 'yeast extract': 0.890909090909091
# Jaro-Winkler similarity between 'yogurt' and 'yogurt lowfat': 0.8923076923076924
# Jaro-Winkler similarity between 'yogurt' and 'yogurt nonfat': 0.8923076923076924
# Jaro-Winkler similarity between 'yogurt' and 'yogurt plain': 0.9
# Jaro-Winkler similarity between 'yogurt lowfat' and 'yogurt nonfat': 0.9384615384615385

# %%
sim_list = []
sim_list.append(smst[0])
for i in range(1,len(smst)):
    k = smst[i]
    if k[0] in sim_list[-1] or k[1] in sim_list[-1]:
        sim_list[-1].append(k[0])
        sim_list[-1].append(k[1])
    else:
        sim_list[-1] = list(set(sim_list[-1]))
        sim_list[-1] = sorted(sim_list[-1], key=len)
        sim_list.append(smst[i])
sim_list[-1] = list(set(sim_list[-1]))
sim_list[-1] = sorted(sim_list[-1], key=len)

# %%
wdf = df.copy()

# %%
def process_ingredients(data, sim_list):
    updated_data = []
    for ing_list in data:
        updated_ings = []
        for ing in ing_list:
            for sims in sim_list:
                if ing in sims:
                    ing = sims[0]
            updated_ings.append(ing)
        updated_data.append(updated_ings)
    return updated_data

wdf['Ingredients'] = process_ingredients(wdf['Ingredients'], sim_list)

# %%
wdf.to_pickle('Recipes_data_Whole_Sim_Ingrs.pkl')
wdf = pd.read_pickle('Recipes_data_Whole_Sim_Ingrs.pkl')

# %%
wdf
# Out:
#                                       Title  \
# 0                     Alice's Key Lime Pie
# 1                 Carrot Cake Muffin Treats
# 2                     Creamy Cucumber Salad
# 3              Creamy Ranch Salad Dressing
# 4                Diabetic Blueberry Muffins
# ...                                     ...
# 9783                Pork and Scallion Wraps
# 9784                  Pork U Pine Meatballs
# 9785                  Portuguese Garlic Dip
# 9786     Potato Skins with Cheese and Bacon
# 9787  Potato Tatin with Brie and Prosciutto
#
#                                             Ingredients        Type
# 0     [lime juice, vanilla bean, sugar substitute, l...    Diabetic
# 1     [raisins seedless, nutmeg, baking soda, walnut...    Diabetic
# 2     [vinegar, garlic, yogurt, black pepper, dill s...    Diabetic
# 3     [oregano, green onions, yogurt, cottage cheese...    Diabetic
# 4     [lemon zest, blueberries, biscuit baking mix b...    Diabetic
# ...                                                 ...         ...
# 9783  [hoisin sauce, pork tenderloin, soy sauce dark...  Appetizers
# 9784           [rice, ground ham, tomato sauce, onions]  Appetizers
# 9785  [mayonnaise, worcestershire sauce, garlic, bla...  Appetizers
# 9786  [chives, russet potatoes, cheddar cheese, sour...  Appetizers
# 9787  [shallots, cream, nutmeg, salt and black peppe...  Appetizers
#
# [9788 rows x 3 columns]

# %%
vectorizer.fit_transform(df['Ingredients'])
len(vectorizer.get_feature_names_out())
# Out:
# /Users/harishneelam/anaconda3/lib/python3.11/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# 2153

# %%
vectorizer.fit_transform(wdf['Ingredients'])
len(vectorizer.get_feature_names_out())
# Out:
# 1615
